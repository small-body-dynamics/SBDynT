# %%
import sys

import sbdynt as sbd

# %% [markdown]
# # *Machine Learning Classification for TNOs*
#
#
# This notebook demonstrates the most basic call to the classifier using ``sbd.run_and_MLclassify_TNO``
#
# If will make a new simulation for the specified TNO with the best-fit orbit and two clones representing 3-sigma minumum and maxiumum semimajor axis orbits (similar to the Gladman et al. 2008 scheme, though we use the JPL covariance matrix to determine the uncertainty in a rather than determining it from observations), run the required integration, and then pass those results through the machine learning classifier to classify each clone. The classifier is described in [Volk & Malhotra 2024](https://ui.adsabs.harvard.edu/abs/2024arXiv240505185V/abstract)
#
# The output (named ``tno_class`` in the example below) is a python class, and you can use the ``print_results`` function to quickly see the classification results
#
# **Note:** The very first time you call any routine using the TNO classifier will take a bit longer because two separate classifiers must be trained on the provided training sets. This has to be done once on every machine you run SBDynT on because it is python environment dependent. But the trained classifiers will then be saved such that they can be loaded quickly on all future uses.
#
# **Two-step classification:** The code first runs a classifier that does not depend at all on resonant angles to determine the probability of resonant classification (see [Volk & Malhotra 2024](https://ui.adsabs.harvard.edu/abs/2024arXiv240505185V/abstract) for details!). For particles with sufficiently high resonant probabilities, a second classifier is run to determine which resonance is librating. The angle is given in the form phi = p*<TNO's mean longitude> - q*<Neptune's mean longitude> - m*<TNO's longitude of perihelion> - n*<TNO's longitude of ascending node>
#
# **Resonant integer values for non-resonant objects:** Sometimes the printed results include specified p, q, m, n for non-resonant clones. This means that the classifier flagged potential resonant behavior, even if the most probable classification was non-resonant. (You can consult the probability values for details!)

# %%
flag, tno_class, sim = sbd.run_and_MLclassify_TNO(
    des="K16F59G", datadir="outputs-from-example-notebooks", logfile="screen", deletefile=True
)
if flag:
    tno_class.print_results()

# %% [markdown]
# If you already ran a classification integration and just need to re-run the classifier, you can use **classify_only** in the function call. You can also easily print a few additional details from the runs

# %%
flag, tno_class, sim = sbd.run_and_MLclassify_TNO(
    des="K16F59G", datadir="outputs-from-example-notebooks", logfile="screen", classify_only=True
)

if flag:
    tno_class.print_results_detailed()

# %% [markdown]
# You can access any of the data features used by the classifier using ``tno_class.features.\<feature name\>``.
# You can print out the full list of features with ``print(tno_class.features.feature_names)``

# %%
print(tno_class.features.a_mean, tno_class.features.e_mean, tno_class.features.i_mean)

# %% [markdown]
# We can plot that integration to do a visual check with the 3:1 resonant angle with ``sbd.plot_resonance``.
#
# ``tno_class.res_p`` ``and tno_class.res_q`` contain an array of the resonant integers for all the particles, so we will use the entry in those arrays for the second clone to define the resonant angle plot

# %%
flag, res_fig = sbd.plot_resonance(
    des="K16F59G",
    planet="neptune",
    p=tno_class.res_p[2],
    q=tno_class.res_q[2],
    datadir="outputs-from-example-notebooks",
)

# %% [markdown]
# **Running with more clones**
#
# You can also run with a larger set of clones sampled in a Gaussian manner using the ``clones`` parameter (you can also set clones=0 to run only the best-fit orbit):

# %%
flag, tno_class_2, sim = sbd.run_and_MLclassify_TNO(
    des="K17A64C", clones=10, datadir="outputs-from-example-notebooks", logfile="screen", deletefile=True
)
if flag:
    tno_class_2.print_results()

# %% [markdown]
# **Here's a plot of the clones in the previous example**

# %%
flag, res_fig = sbd.plot_resonance(
    des="K17A64C",
    planet="neptune",
    p=tno_class_2.res_p[0],
    q=tno_class_2.res_q[0],
    datadir="outputs-from-example-notebooks",
)

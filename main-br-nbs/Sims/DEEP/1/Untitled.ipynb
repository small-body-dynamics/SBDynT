# %%
import rebound
import numpy as np

archive = rebound.SimulationArchive('../4/archive_ias15.bin')

rebound.OrbitPlot(archive[0])
# Out:
# (<Figure size 360x360 with 1 Axes>, <AxesSubplot:xlabel='x', ylabel='y'>)

# %%
np.sqrt(0.253**2+1.123**2+0.029**3)
np.sqrt(0.16842231327432977**2+0.06166890475019255**2+0.046116510167293755**2)
# Out:
# 0.18519141970343797

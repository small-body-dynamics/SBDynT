# %%
import rebound

s = rebound.Simulationarchive('Helga-simarchive.bin')

print(s[-1].t)
print(s[-1].t/5e6)

sa = s[-10]
#sa.move_to_com()
com = sa.com()
#com = sa.particles['sun']
print(sa.particles['Helga'].orbit(primary=com))
# Out:
# -5000000.0
# -1.0
# <rebound.Orbit instance, a=3.6399410749838497 e=0.06710233037199233 inc=0.0864001410336321 Omega=1.7842980611707964 omega=2.731823754449337 f=4.222634694662288>

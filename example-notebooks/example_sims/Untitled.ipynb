# %%
import rebound

sa = rebound.Simulation('Albion-ic.bin')

print(sa.particles['Albion'])

s = rebound.Simulationarchive('Albion-simarchive.bin')
print(s[-1].particles['Albion'])
# Out:
# <rebound.particle.Particle object at 0x207b0fc51d0, m=0.0 x=36.213416762281526 y=19.543547436841884 z=0.7599519561637235 vx=-0.45443645544711725 vy=0.9019073677616892 vz=0.03424007262994995>
# <rebound.particle.Particle object at 0x207b0fc6650, m=0.0 x=-46.48887699648532 y=4.8699434422627546 z=-0.4997128162711876 vx=-0.11866076962180702 vy=-0.8812343826699238 vz=-0.027530376500525814>

# %%
for i in s:
    print(len(i.particles))
    print(i.particles['Albion'])
# Out:
# 9
# ---------------------------------------------------------------------------
# ParticleNotFound                          Traceback (most recent call last)
# Cell In[8], line 3
#       1 for i in s:
#       2     print(len(i.particles))
# ----> 3     print(i.particles['Albion'])
#
# File ~\anaconda3\Lib\site-packages\rebound\particles.py:67, in Particles.__getitem__(self, key)
#      65     return p.from_address(addressof(ptr.contents))
#      66 else:
# ---> 67     raise ParticleNotFound("Particle was not found in the simulation.")
#
# ParticleNotFound: Particle was not found in the simulation.

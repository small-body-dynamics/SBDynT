# %%
import rebound

s = rebound.Simulationarchive('Lempo-ic.bin')
print(len(s[0].particles))
print(len(s[-1].particles))
s = None
# Out:
# 9
# 9

# %%
len(s[0].particles)
# Out:
# 9

# %%
len(s[0].particles)
# Out:
# 9

# %%
len(s[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 len(s[0])
#
# TypeError: object of type 'Simulation' has no len()

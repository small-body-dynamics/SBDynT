# %%
import numpy as np
import rebound
import os

folders = os.listdir('.')
num = 0
for i in folders:
    if os.path.isfile(str(i)+'/archive_init.bin'):
        num = num+1
print(num)
# Out:
# 1994

# %%
s = rebound.Simulationarchive('2015 RT277/archive_init.bin')
print(len(s[0].particles))
# Out:
# 15

# %%
import numpy as np
import os
import pathlib
import shutil
folders = os.listdir('.')
count = 0
                 
for i in folders:
    if os.path.isfile(str(i)+'/archive_init.bin'):
        count = count+1

print(count)
# Out:
# 4009

# %%
print(len(os.listdir('.')))
# Out:
# 2082

# %%
import pathlib

pathlib.Path.rmdir()

# %%
import rebound
s = rebound.Simulation('2024 TF3/archive_init.bin')
print(len(s.particles))
# Out:
# 15

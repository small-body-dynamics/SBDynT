# %%
import numpy as np
import os

files= np.sort(os.listdir('MOTNOs/'))
print(np.where(files == '2013 SB113'))
print(np.where(files == '2007 FO51'))
print(files[files == '2013 SB113'])
print(len(files))
print(files)
# Out:
# (array([998], dtype=int64),)
# (array([573], dtype=int64),)
# ['2013 SB113']
# 4013
# ['.ipynb_checkpoints' '118228' '118378' ... '95625' 'Untitled.ipynb'
#  'Untitled1.ipynb']

# %%
import pandas as pd

data = pd.read_csv('data_files/MOTNOs.csv',index_col=0)
vals = data['Name'].values

missing = np.setdiff1d(vals,files)
print(len(missing))
# Out:
# 0

# %%
G = 6.673e-11
a = 40*1.496e11
np.sqrt(G/a)
# Out:
# 3.3393717587767174e-12

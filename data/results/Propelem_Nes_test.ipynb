# %%
import rebound
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import os

if 'Propelem_Nes_test.ipynb' in os.listdir():
    os.chdir('../../src')
import prop_elem
import prop_elem_og
import tools

#astdys = pd.read_csv('../data/data_files/NesvornyAst.csv')
#print(astdys.iloc[5312])
#TNOs = pd.read_csv('../data/results/NesvornyAst_100yr_prop_elem_multi_5win_helio_100yr?.csv')
#print(TNOs.iloc[5312])

objname = '5593'
objname = '2293'
objname = '1264'
objname = '2009'
objname = '9931'
objname = '58'#Negative g frequency

#objname ='896' # Good if protect 2 indices?
#objname = '9973' #Good
objname = '2' # Negative g frequency
#objname = '1139' # Very chaotic, wide frequencies
#objname = '1168' # Good; check 100 yr
#objname = '1313' # Good; check 100 yr
#objname = '739' #Bad inc
#objname = '2548' #Bad inc
#objname = '929' #Bad inc
#objname = '4276' #Bad inc
objname = '413'
objname = '1025'
objname = '1103'
#objname = '71'
objname = '594'
objname = '132'
#objname = '9936'
objname = '1747'
#objname = '122' # OrbFit and I filter out the short-period oscillations by Jupiter. Nesvorny doesn't mention doing this, and there is a feature in both our residuals at 3.2 AU.
#objname = '175' # OrbFit and I filter out the short-period oscillations by Jupiter. Nesvorny doesn't mention doing this, and there is a feature in both our residuals at 3.2 AU.
dt = 1000
#objname = '31' #Strong signal at 10,000 years in incliantion; Identified to be e*sini resonance, want to keep
objname = '210' #
objname = '344' #Needed a larger inclination spread
objname = '3789' #
objname = '40' #I identify another frequencyt as the dominant frequency, 48000 years rather than 38000
objname = '70' #Interesetingly, I see no reason why it should differ, my filter seems to do everything fine.
objname = '86'
objname = '136' #I think I do a better job
objname = '175' #Needs wide filter, frequency at 3000 years
objname = '786'
objname = '8906' #NEsvorny idenitfies super lower frequency as g, I identify a higher one. Hard to tell difference. Technically more power is contained in lower. 
objname = '8998' #Same again, very low dominant frequency at 430 arcsec/year. I identify a higher one as dominant. 
objname = '9858' #Same again, very low dominant frequency at 430 arcsec/year. I identify a higher one as dominant. 
objname = '270' #Same again, very low dominant frequency at 430 arcsec/year. I identify a higher one as dominant. 
objname = '290'
#objname = '502' #Strong s6 and s6-s7 frequencies, not filtering makes the proper elements too large
objname='5' #Ecc needs ot be thin
objname='149' #SinInc needs to be thick
#objname = '119'
#objname = '6251'
#objname = '4582'
#objname = '2352'
#objname = '7142'
#objname = '1762'
#objname= '149'
#objname='5959'
#objname='4846'
objname = '3262'
objname = '1003'
#objname = '1009' #This object is ejected in simulation. Should we calcualte proper elements for pre-ejection values?
objname='168'
objname='7892'
objname = '24' #Has an alias from below Nyquist frequency short-period effects (Jupiter interaction)
objname = '48' #Has an alias from below Nyquist frequency short-period effects (Jupiter interaction) Disappears with high reoslution
#objname = '147' #Dominant frequency is actually an alias itself at -462 arcsec/yr
#objname = '286' 
#objname = '1558'
objname = '55638' #Very chaotic evolution, peak frequency is wide at long period frequency
objname = '59358'
objname = '55638'
objname = '136120'





filename = 'Single'
#filename = 'NesvornyAst_full'
filename = 'TNOs_back'

'''
filename = 'TNOs_back'
#objname = '19299' #
objname='20108' #Improved, but sitll off by 0.008 eccentricity
objname='38083' #AstDys integrated frowards for this one, can tell. proper element is supposed to be lower.
objname = '2015 FO345'
objname = '24952'
objname = '2016 BP81'
objname = '38628'
objname = '66652'
#filename = 'NesvornyAst_100yr'
dt = 10000
#'''
windows=5
home = str(os.path.expanduser("~"))
        #print(os.listdir(home+'/../../../hdd/haumea-data/djspenc/SBDynT_sims/NesvornyAst/13/'))
fullfile=home+'/../../../hdd/haumea-data/djspenc/SBDynT_sims/'+filename+'/'+objname+'/archive.bin'
fullfile='../data/'+filename+'/'+objname+'/archive.bin'
#archive = rebound.SimulationArchive(fullfile)

# %%
#[np.nanmedian(a),np.median(ecc_f[pc5:-pc5]),np.nanmedian(sini_f[pc5:-pc5])],Yhk_f,Ypq_f,h,k,p,q,freq1,freq2,g,s
#print(prop_elem.prop_calc(objname,filename,windows,True))
pes,error_list,rms,g_arr,s_arr, hk_arr, pq_arr, hk_new, pq_new, g, s_freq, hk_sig, pq_sig = prop_elem.prop_calc(objname,filename,windows,True)

#[np.nanmedian(a),np.median(ecc_f[pc5:-pc5]),np.nanmedian(sini_f[pc5:-pc5])],Yhk_f,Ypq_f,h,k,p,q,freq1,freq2,g,s
#pes,Yhk_f,Ypq_f,h,k,p,q,freq1,freq2,g,s = prop_elem_og.prop_calc(objname,filename,windows,True)
s = rebound.Simulationarchive(fullfile)
# Out:
# ../data/TNOs_back/136120/archive.bin
# 18277012.378242664 -16668833.399999449
# dt 5000.399999999834 tol 9.999200063995212e-09 N 20001 protect_g 50 protect_s 20 kernel_g 2 kernel_s 2

# %%
1/10001/1000
print(1/g)

# %%
hk = hk_arr
pq = pq_arr

hkn = hk_new
pqn = pq_new
'''
hk = k+1j*h
pq = q+1j*p

hkn = np.fft.ifft(Yhk_f)
pqn = np.fft.ifft(Ypq_f)

hk_new = hkn
pq_new = pq
'''
t = np.linspace(0,abs(s[-1].t),len(hk))

fig,ax=plt.subplots(2,figsize=(6,6),sharex=True)
fig.subplots_adjust(hspace=0,wspace=0.025)
ax[0].plot(t,np.abs(hk),alpha=0.5)
ax[0].plot(t,np.abs(hkn),alpha=0.5)
ax[0].plot(t,np.ones(len(hkn))*np.mean((np.abs(hkn))))
y0,y1 = ax[0].get_ylim()
ax[0].vlines([0.025*t[-1],0.975*t[-1]],ymin=y0,ymax=y1,colors='k')
ax[0].set_ylim(y0,y1)
#ax[0].set_title('Eccentricity')
#plt.xlim(1000,10000)
#plt.ylim(0,1)
#ax[0].set_xlabel('Time(yrs)')
#ax[0].set_xlabel('Time(yrs)')
fig.supxlabel('Time(yrs)',y=0.025)
#plt.show()
#ax[1].plot(t,np.arcsin(np.abs(pq))*180/np.pi)
#ax[1].plot(t,np.arcsin(np.abs(pqn))*180/np.pi)
ax[1].plot(t,(np.abs(pq)),alpha=0.5)
ax[1].plot(t,(np.abs(pqn)),alpha=0.5)
ax[1].plot(t,np.ones(len(pqn))*np.mean((np.abs(pqn))))

y2,y3 = ax[1].get_ylim()
ax[1].vlines([0.025*t[-1],0.975*t[-1]],ymin=y2,ymax=y3,colors='k')
ax[1].set_ylim(y2,y3)
#ax[1].set_title('Inclination (deg)')
ax[1].set_ylabel('Inc (deg)',fontsize=12)
#ax[1].yaxis.set_label_position("")

# Move the y-axis ticks to the right
#ax[1].yaxis.tick_right()
ax[0].set_ylabel('Ecc',fontsize=12)
fig.suptitle('Asteroid ('+str(objname)+') Proserpina',fontsize=14,x=0.52,y=0.94)
#ax[0].set_xlim(-3e5,1e8+3e5)
#ax[1].set_xlim(-3e5,1e8+3e5)
#fig.tight_layout()
plt.savefig('../data/results/eccandinc.pdf')
plt.show()

print(pes)
#'''
print(pes)
print(error_list)
print('std',np.std(error_list,axis=0))
print('rms',np.sqrt(np.nanmean((np.array(error_list)-np.array(pes))**2,axis=0)))
print('outrms',rms)
errs = np.std(error_list,axis=0)

def hcm(a,rms_a,rms_e,rms_i):
    F = 365*24*60*60/1.496e11
    return (2*np.pi*1/F*np.sqrt((5/4*(rms_a/a)**2+2*rms_e**2+2*rms_i**2)/a))

print(hcm(pes[0],errs[0],errs[1],errs[2]))
print(hcm(pes[0],*np.sqrt(np.nanmean((np.array(error_list)-np.array(pes))**2,axis=0))))
print(hcm(pes[0],*np.std(error_list,axis=0)))
#df = pd.read_csv('../data/results/NesvornyAst_prop_elem_multi_5win_helio_1000.csv')
#num = 12
#print(hcm(df['PropSMA'].iloc[num],df['RMS_err_a'].iloc[num],df['RMS_err_e'].i?loc[num],df['RMS_err_sinI'].iloc[num]))
#print(df.iloc[num])
#'''

#print(np.mean(np.abs(pq)),np.mean(np.abs(pq)*180/np.pi))
#print(np.mean(np.abs(pq_new)),np.mean(np.abs(pq_new)*180/np.pi))
N = len(pq)
#print(np.mean(np.abs(pq_new[int(0.05*N):int(0.95*N)])),np.mean(np.abs(pq_new[int(0.05*N):int(0.95*N)])*180/np.pi))
# Out:
# [64.02658612  0.49752405  0.35592312]
# [64.02658612  0.49752405  0.35592312]
# [[63.25605619  0.48384974  0.36055132]
#  [63.73189973  0.49295612  0.35847148]
#  [64.34876851  0.49980979  0.358797  ]
#  [64.82619466  0.50332511  0.35185929]
#  [64.79712411  0.5046128   0.3472041 ]]
# std [0.61329234 0.00768244 0.00504413]
# rms [0.63521029 0.00770688 0.00507365]
# outrms [0.61329234 0.00768244 0.00504413]
# 62.73211762629601
# 63.79517247642092
# 62.73211762629601

# %%
print(1/np.array(g_arr[:7]))
print(1/np.array(s_arr[:7]))

print(1/g[0])
print(1/s_freq[0])
# Out:
# [ -304917.68414633   -45877.52311926  -420222.69075629 -1923326.93076917
#    -24804.81160714   -24263.22183406   -16997.45078178]
# [  49218.99625984  432956.7116883  1887037.74339616  -24804.81160714
#   -24263.22183406  -16997.45078178  -47853.11023923]
# -4167208.3499998623
# 7693307.723076668

# %%
print((0.152629651-0.152781)/2.4e-6)
print((0.0189061-0.01890034)/0.48e-6)

print(1e-3*2*np.pi*206265)
print(1.2e-3*2*np.pi*206265)
print(g[0])
print(1/g[0])
print(1/(3*g[0]))
dt=abs(s[1].t)
fig,ax = plt.subplots(1,2,figsize=(10,3))
#dt = 10000
freq = np.fft.fftfreq(len(hk),dt)
freq_sig = np.fft.fftfreq(len(hk_sig),dt)
print(len(hk_sig),len(freq))
ax[0].scatter(1/np.flip(freq_sig),np.abs(hk_sig)**2,s=5)
ax[0].set_yscale('log')
ax[0].set_xscale('log')
#plt.show()
ax[1].scatter(1/np.flip(freq),np.abs(np.fft.fft(hk))**2,s=5)
ax[0].vlines(abs(1/np.array(g_arr)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],alpha=0.3)
ax[1].vlines(abs(1/g),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='r')
ax[1].vlines(abs(1/g[0]),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='g')
ax[1].set_yscale('log')
ax[1].set_xscale('log')

ax[0].set_xlim(1e2,1e4)
ax[1].set_xlim(1e2,1e4)
#ax[0].set_xlim(abs(1/g[0])-1e3,abs(1/g[0])+1e3)
#ax[1].set_xlim(abs(1/g[0])-1e3,abs(1/g[0])+1e3)
plt.show()

fig,ax = plt.subplots(1,2,figsize=(10,3))
#dt = 10000
freq = np.fft.fftfreq(len(hk),dt)
freq_sig = np.fft.fftfreq(len(hk_sig),dt)
print(len(hk_sig),len(freq))
ax[0].scatter(-1/np.flip(freq_sig),np.abs(hk_sig)**2,s=5)
ax[0].set_yscale('log')
ax[0].set_xscale('log')
#plt.show()
ax[1].scatter(-1/np.flip(freq),np.abs(np.fft.fft(hk))**2,s=5)
ax[0].vlines(abs(1/np.array(g_arr)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],alpha=0.3)
ax[1].vlines(abs(1/g),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='r')
ax[1].vlines(abs(1/g[0]),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='g')
ax[1].set_yscale('log')
ax[1].set_xscale('log')

ax[0].set_xlim(1e2,1e4)
ax[1].set_xlim(1e2,1e4)
#ax[0].set_xlim(abs(1/g[0])-1e3,abs(1/g[0])+1e3)
#ax[1].set_xlim(abs(1/g[0])-1e3,abs(1/g[0])+1e3)
plt.show()

ind_short = np.where(abs(1/freq) < 3000)[0]
#ind_short = np.intersect1d(ind_short,np.where(abs(1/freq) > 320)[0])
freq_short = freq[ind_short]
Yhk_short = np.fft.fft(hk)[ind_short]
Yhk = np.fft.fft(hk)

#print('Freq:',freq_short[np.argmax(np.abs(Yhk_short)**2)])
#print('Period',1/freq_short[np.argmax(np.abs(Yhk_short)**2)])
#print('Power',np.abs(Yhk_short[np.argmax(np.abs(Yhk_short)**2)])**2)
#print('Power Max',np.abs(Yhk[np.argmax(np.abs(Yhk)**2)])**2)
#print(s_freq[0])
#print(g[0])

#print(1/(5*g[0]))
# Out:
# -63.06208333333128
# 11.999999999993788
# 1296.0012173853975
# 1555.2014608624766
# -2.399688030957303e-07
# -4167208.3499998623
# -1389069.4499999539
# 20001 20001
# 20001 20001

# %%
3146/166285
# Out:
# 0.018919325254833568

# %%
print(1/(g_arr[0]+s_arr[0]))
print(1/(g_arr[1]+s_arr[0]))
print(1/2/(g[0]-g_arr[0]+g[1]))
print(1/(g_arr[0]+s_arr[0]))
print(1/6/g[0])
print(1/g)
print('1-6',1/(g[0]-6*s_freq[0]))
print('5-1',1/(5*g[0]-1*s_freq[0]))
print(1/(g[0]-3*s_freq[0]))
print(1/abs(g[0]-s_freq[0])**0.5)
print(1/(g[0]-s_freq[0]))
print(1/(g[0]+s_freq[0]))
print(1/(2*g[0]-4*s_freq[0]))
print(1/g[0])
print(1/s_freq[0])

# %%
print(1/3/(g[0]-g_arr[1]-s_freq[0]-s_arr[0]))
print(1/(g_arr[1]-s_freq[0]+s_arr[0]))
print(1/g[0])
print(1/s_freq[0])
print(1/(g_arr[1]+s_arr[0]))
# Out:
# 1132.5921331759312
# -15190.737610528056
# 2800.0218200442723
# 15544.902922190759
# -666746.6679995535

# %%
print(1/(10*g[0]+7*s_freq[0]))
print(1/(5*g[0]-s_freq[0]))
print(1/(4*g[0]-s_freq[0]))
print(1/(2*gs-g6*2+ss-s6))
print(1/(2*gs-g5*2+ss-s7))
print(1/4/g[0])
print(1/4/(gs-g5-g6))
print(1/4/(gs+g6+g5))
# Out:
# 248.65050430226367
# 580.932426116938
# 733.0139441655807
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2 print(1/(5*g[0]-s_freq[0]))
#       3 print(1/(4*g[0]-s_freq[0]))
# ----> 4 print(1/(2*gs-g6*2+ss-s6))
#       5 print(1/(2*gs-g5*2+ss-s7))
#       6 print(1/4/g[0])
#
# NameError: name 'gs' is not defined

# %%
#dt = 10000
plt.figure(figsize=(12,4))
freq = np.fft.fftfreq(len(hk),dt)
freq_sig = np.fft.fftfreq(len(hk_sig),dt)
#print(len(hk_sig),len(freq))
plt.scatter(-1/(freq_sig),np.abs(np.fft.fft(hk))**2,s=5,alpha=0.6)
plt.yscale('log')
plt.xscale('symlog',linthresh=4e2,linscale=0.0000001)
#plt.show()
#ax[1].scatter(1/np.flip(freq),np.abs(np.fft.fft(hk))**2,s=5)
plt.vlines(abs(1/np.array(g_arr)),ymin=plt.ylim()[0],ymax=plt.ylim()[1],alpha=0.3,label='Filtered Freqs')
plt.vlines(-abs(1/np.array(g_arr)),ymin=plt.ylim()[0],ymax=plt.ylim()[1],alpha=0.3)
plt.vlines(abs(1/np.array(g)),ymin=plt.ylim()[0],ymax=plt.ylim()[1],alpha=0.3,colors='r',label='Protected Freqs')
plt.vlines(abs(1/np.array(g[0])),ymin=plt.ylim()[0],ymax=plt.ylim()[1],alpha=0.9,colors='g',label='Dominant Freq')
plt.vlines(-abs(1/np.array(g)),ymin=plt.ylim()[0],ymax=plt.ylim()[1],alpha=0.3,colors='r')

plt.title('Asteroid #46 Eccentricity Full Power Spectrum: 1000 Year Resolution')
#ax[1].set_title('Eccentricity UnFiltered')
plt.xlabel('Period (yrs)')
#ax[1].set_xlabel('Period (yrs)')
plt.ylabel('Power Spectrum')
plt.legend()


#ax[0].set_xlim(2.5e2,1e7)
#ax[1].set_xlim(2e3,1e7)
plt.savefig('ecc_1000yr.pdf')
plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(10,3))
dt = abs(s[1].t-s[0].t)
freq = np.fft.fftfreq(len(hk),dt)
freq_sig = np.fft.fftfreq(len(hk_sig),dt)
print(len(hk_sig),len(freq))
ax[0].scatter(1/np.flip(freq_sig),np.abs(hk_sig)**2,s=5)
ax[0].set_yscale('log')
ax[0].set_xscale('log')
#plt.show()
ax[1].scatter(1/np.flip(freq),np.abs(np.fft.fft(hk))**2,s=5)
ax[0].vlines(abs(1/np.array(g_arr)),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],alpha=0.3,label='Filtered Freqs')
ax[1].vlines(abs(1/g),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='r',label='Protected Freqs')
ax[1].vlines(abs(1/g[0]),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='g')
print(abs(1/g[0]))
ax[1].set_yscale('log')
ax[1].set_xscale('symlog',linthresh=1e2,linscale=0.05)
ax[1].set_xscale('log')
ax[0].set_title('Eccentricity Filtered')
ax[1].set_title('Eccentricity UnFiltered')
ax[0].set_xlabel('Period (yrs)')
ax[1].set_xlabel('Period (yrs)')
ax[0].set_ylabel('Power Spectrum')
ax[0].legend()
ax[1].legend()

#ax[0].set_xlim(2.5e2,1e7)
#ax[1].set_xlim(2e3,1e7)
plt.show()


fig,ax = plt.subplots(1,2,figsize=(10,3))
#dt = 10000
freq = np.fft.fftfreq(len(hk),dt)
freq_sig = np.fft.fftfreq(len(hk_sig),dt)
print(len(hk_sig),len(freq))
ax[0].scatter(-1/np.flip(freq_sig),np.abs(hk_sig)**2,s=5)
ax[0].set_yscale('log')
ax[0].set_xscale('log')
#plt.show()
ax[1].scatter(-1/np.flip(freq),np.abs(np.fft.fft(hk))**2,s=5)
ax[0].vlines(abs(1/np.array(g_arr)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],alpha=0.3)
ax[1].vlines(abs(1/g),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='r')
ax[1].set_yscale('log')
ax[1].set_xscale('log')

#ax[0].set_xlim(2e3,1e8)
#ax[1].set_xlim(2e3,1e8)
#ax[0].set_xlim(abs(1/g[0])-1e3,abs(1/g[0])+1e3)
#ax[1].set_xlim(abs(1/g[0])-1e3,abs(1/g[0])+1e3)
plt.show()

fig,ax = plt.subplots(1,2,figsize=(10,3))
#freq = np.fft.fftfreq(len(hk_new),dt)
ax[0].scatter(-1/(freq_sig),np.abs((hk_sig))**2,s=5)
ax[0].set_yscale('log')
ax[0].set_xscale('log')
#plt.show()
freq = np.fft.fftfreq(len(hk),dt)
#freq = np.arange(len(hk))
#freq = np.fft.fftfreq(len(hk_sig),dt)
ax[1].scatter(-1/(freq),np.abs(np.fft.fft(hk))**2,s=5)
ax[1].vlines(abs(1/g),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='r',alpha=0.3)
ax[0].vlines(abs(1/g),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='r',alpha=0.3)
ax[0].vlines(abs(1/np.array(g_arr)),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],alpha=0.3)
ax[1].vlines(abs(1/np.array(g_arr)),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],alpha=0.3)
#ax[1].vlines(abs(1/np.array(g_arr)),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1])
#ax[1].vlines(abs(1/g),ymin=ax[1].get_ylim()[0],colors='r',ymax=ax[1].get_ylim()[1])
ax[1].set_yscale('log')
ax[1].set_xscale('log')
ax[0].set_xlim(2e3,1e8)
ax[1].set_xlim(2e3,1e8)
ax[0].set_xlim(abs(1/g[0])-2e4,abs(1/g[0])+5e4)
ax[1].set_xlim(abs(1/g[0])-2e4,abs(1/g[0])+5e4)

ax[0].set_title('Eccentricity Filtered')
ax[1].set_title('Eccentricity UnFiltered')
ax[0].set_xlabel('Period (yrs)')
ax[1].set_xlabel('Period (yrs)')
ax[0].set_ylabel('Power Spectrum')
#ax[0].set_xlim(6.9e3,9.1e3)
#ax[1].set_xlim(6.9e3,9.1e3)

plt.show()

print('inc')
fig,ax = plt.subplots(1,2,figsize=(10,3))
freq = np.fft.fftfreq(len(pq_new),dt)
#freq = np.fft.fftfreq(len(hk_sig),dt)
ax[0].scatter(1/(freq_sig),np.abs((pq_sig))**2,s=2)
#ax[0].vlines(abs(1/np.array(s_arr)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].vlines(abs(1/s_freq),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],colors='r')
#ax[1].vlines(abs(1/s_freq),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='r')

#ax[0].vlines(abs(1/extras),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],colors='r')
#ax[1].vlines(abs(1/extras),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='r')
#ax[1].vlines(abs(1/np.array(s_arr)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(abs(-1/np.array(s_arr)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
ax[0].vlines(abs(1/np.array(s_arr)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],alpha=0.2,label='Filtered Freqs')
ax[1].vlines(abs(1/np.array(s_freq)),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],alpha=0.2,label='Protected Freqs')
#ax[1].vlines(49266,ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(abs(1/np.array(new)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(abs(-1/np.array(new)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].vlines(1/np.array(s_arr),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].vlines(1/(s_freq*2),ymin=1e-3,ymax=1e4,colors='g')
#ax[1].vlines(1/(s_freq*2),ymin=1e-3,ymax=1e4,colors='g')
ax[0].set_yscale('log')
ax[0].set_xscale('log')
#plt.show()
freq = np.fft.fftfreq(len(pq),dt)
ax[1].scatter(1/(freq),np.abs(np.fft.fft(pq))**2,s=2)
ax[1].vlines(abs(1/s_freq),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='r')
ax[1].set_yscale('log')
ax[1].set_xscale('log')


ax[0].set_title('Inclination Filtered')
ax[1].set_title('Inclination UnFiltered')
ax[0].set_xlabel('Period (yrs)')
ax[1].set_xlabel('Period (yrs)')
ax[0].set_ylabel('Power Spectrum')
ax[0].legend()
ax[1].legend()

plt.show()

fig,ax = plt.subplots(1,2,figsize=(10,3))
freq = np.fft.fftfreq(len(pq_new),dt)
#freq = np.fft.fftfreq(len(hk_sig),dt)
ax[0].scatter(1/(freq_sig),np.abs((pq_sig))**2,s=2)
#ax[0].vlines(abs(1/np.array(s_arr)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].vlines(abs(1/s_freq),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],colors='r')
#ax[1].vlines(abs(1/s_freq),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='r')

#ax[0].vlines(abs(1/extras),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],colors='r')
#ax[1].vlines(abs(1/extras),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='r')
ax[0].vlines(abs(1/np.array(s_arr)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],alpha=0.3)
ax[0].vlines(abs(1/np.array(s_freq)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],alpha=0.3,colors='r')
ax[1].vlines(abs(1/np.array(s_arr)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],alpha=0.3)
#ax[1].vlines(abs(-1/np.array(s_arr)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(49266,ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(abs(1/np.array(new)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(abs(-1/np.array(new)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].vlines(1/s_freq,ymin=1e-3,ymax=1e4)
#ax[0].vlines(1/(s_freq*2),ymin=1e-3,ymax=1e4,colors='g')
#ax[1].vlines(1/(s_freq*2),ymin=1e-3,ymax=1e4,colors='g')
ax[0].set_yscale('log')
ax[0].set_xscale('log')
#plt.show()
freq = np.fft.fftfreq(len(pq),dt)
ax[1].scatter(1/(freq),np.abs(np.fft.fft(pq))**2,s=2)
ax[1].vlines(abs(1/s_freq),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='r')
ax[1].set_yscale('log')
ax[1].set_xscale('log')
ax[0].set_xlim(abs(1/s_freq[0])-9e3,abs(1/s_freq[0])+5e4)
ax[1].set_xlim(abs(1/s_freq[0])-9e3,abs(1/s_freq[0])+5e4)
plt.show()

fig,ax = plt.subplots(1,2,figsize=(10,3))
#freq = np.fft.fftfreq(len(pq_new),dt)
#freq = np.fft.fftfreq(len(hk_sig),dt)
ax[0].scatter(1/np.flip(freq_sig),np.abs((pq_sig))**2,s=5)
ax[0].vlines(1/s_freq,ymin=1e-3,ymax=1e4,colors='r')
#ax[0].vlines(-1/(s_freq*2),ymin=1e-3,ymax=1e4,colors='g')
ax[0].set_yscale('log')
ax[0].set_xscale('log')
#plt.show()
freq = np.fft.fftfreq(len(pq),dt)
ax[1].scatter(1/np.flip(freq),np.abs(np.fft.fft(pq))**2,s=5)
#ax[1].vlines(49266,ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1])
#ax[0].vlines(49266,ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].vlines(-1/np.array(s_arr),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(-1/np.array(s_arr),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
ax[1].vlines(1/s_freq,ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],colors='g')
#ax[1].vlines(1/s_ex,ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].set_xlim(6e3,2e4)
#ax[1].set_xlim(8e3,6e4)
ax[1].set_yscale('log')
ax[1].set_xscale('log')
plt.show()

half = int(N/2)

#print(1/extras)
# Out:
# 20001 20001
# 16668833.399999449
# 20001 20001
# inc

# %%
print(1/np.array(g_arr))
print(g_arr[3]*2*np.pi*206265)
# Out:
# [ -304920.73292669   -45899.03643871  -420226.89243678 -1923346.16153755
#    -24817.36982629   -24275.24281552   -17006.29151504   -47876.49612252
#    -44078.44883206   -15890.3718462    -46954.92976524    65669.07445828
#    -11872.50716998]
# -0.6738262946641661

# %%
print(17.33/2/np.pi/206265)
print(18.00/2/np.pi/206265)

print(1/1.337e-5)
print(1/1.388e-5)

print(1/np.array(s_arr))
print(1/np.array(g_arr))

print(1/s_freq)


print(1/(g_arr[1]-g_arr[0]+s_arr[0]+s_arr[1]))

print(1/9e-4)
# Out:
# 1.3371901019477595e-05
# 1.3888875842504138e-05
# 74794.31563201196
# 72046.10951008646
# [  49266.25625616  434828.26173915 2000210.00400007   69937.41272728
#    73000.36510949  208355.20875001  -24816.50129032  -24274.39325243
#   -17008.58846939  -47851.91397129  -44057.48907489  -15899.92054054
#   -46953.28647887   65796.38171053]
# [ -303062.12181819   -45876.37623853  -416710.41750001 -2000210.00400007
#   -181837.27309092   -73537.1325       -75765.53045455   -24816.50129032
#    -24274.39325243   -17008.58846939   -47851.91397129   -44057.48907489
#    -15899.92054054   -46953.28647887    65796.38171053]
# [ 15785.46312139   7892.73156069  -6910.71730072  -4423.68
#   -4806.48598416 -55543.42616949]
# 243928.04926830129
# 1111.111111111111

# %%
print(10**np.log10(1/4000))
print(np.log10(1/4000))
print(10**(-0.36))
#1/4000
10**(-0.34020599)
#1/0.02025
# Out:
# 0.00024999999999999995
# -3.6020599913279625
# 0.436515832240166
# 0.4568714397500157

# %%
print(1/(6*g[0]+2*s_freq[0]))
print(1/g)
print(1/s_freq[0])
print(1/(g[0]+s_freq[0]-g_arr[1]))
print(1/(g_arr[1]-s_freq[0]))
print(1/(g_arr[1]+s_arr[0]))
print(1/(4*g[0]-s_freq[0]))
# Out:
# -2766.854224924109
# [-12292.05605401  -6146.02802701   2198.          -6910.71730072
#   -4423.68        -4806.48598416 -55543.42616949]
# 15785.463121387833
# 263589.31987805694
# -11744.376307512217
# -666736.6680000222
# -2572.2622794349404

# %%
print(1/(g[0]+s_freq[0]-g_arr[1]-s_arr[0]))
print(1/g[0])
print(1/s_freq[0])
print(1/(s_freq[0]-g_arr[1]-s_arr[0]))
print(g[0]-1/2090)
print(1/(g[0]+1/2090))
# Out:
# -60591.04773907456
# -12292.056054013932
# 15785.463121387833
# 15420.374819346576
# -0.0005598222545343773
# 2518.1587923917946

# %%
g5 = g_arr[0]
g6 = g_arr[1]
s6 = s_arr[0]
s7 = s_arr[1]
gs = g[0]
ss = s_freq[0]

print(1/(-gs+ss+g6-s6))
print(1/(gs-ss+g6-s6))
print(1/(ss+g5-g6-s6))
print(1/(ss-g5+g6-s6))
print(1/(gs+g5-2*g6-s6+s7))
print(1/(ss-2*g6+s6))
print(1/(ss-g5-g6+s6))
print(1/(g6+s6))
print(1/(gs+ss))
# Out:
# 9745.904830988218
# -5353.366082427602
# 16247.055793336393
# 40727.39471777248
# -16933.167542780728
# 7858.996073465442
# 9195.854046279108
# -666736.6680000222
# -55543.42616949346

# %%
import scipy as sp
plt.plot(np.abs(hk_arr)*sp.signal.windows.flattop(len(hk_arr)))
plt.show()
win_hk = np.abs(hk_arr)*sp.signal.windows.flattop(len(hk_arr))

freqs = np.fft.fftfreq(len(hk_arr),1000)
plt.scatter(-1/freqs,np.abs(np.fft.fft(win_hk))**2,s=5)
plt.xscale('log')
plt.yscale('log')
plt.show()

plt.plot(np.abs(hk_new)*sp.signal.windows.flattop(len(hk_arr)))
plt.show()
win_hk = np.abs(hk_new)*sp.signal.windows.flattop(len(hk_arr))

power = np.abs(np.fft.fft(win_hk))**2
freqs = np.fft.fftfreq(len(hk_arr),1000)
plt.scatter(-1/freqs,np.abs(np.fft.fft(win_hk))**2,s=5)
plt.xscale('log')
plt.yscale('log')
plt.show()

ind = np.where(abs(1/freqs) < 1e6)[0]
power_sub = power[ind]
win_hk_sub = np.fft.fft(win_hk)[ind]
print(abs(win_hk_sub[np.argmax(power_sub)])*2)
print(power_sub[np.argmax(power_sub)])
print(power_sub[np.argmax(power_sub)]/np.sum(sp.signal.windows.flattop(len(hk_arr))))
print(np.sum(sp.signal.windows.flattop(len(hk_arr))))
print(np.sum(sp.signal.windows.flattop(len(hk_arr)))/len(hk_arr))
#print(np.sqrt(power_sub[np.argmax(power_sub)])/np.sum(sp.signal.windows.flattop(len(hk_arr))))
# Out:
# 0.9657327428234117
# 0.23315993264030746
# 0.00010815526199528695
# 2155.789078949
# 0.21555735215968405

# %%
print(1/np.array(g_arr))
print(1/np.array(s_arr))

print(2*np.pi*206265*np.array(g_arr[:7]))
print(2*np.pi*206265*np.array(s_arr[:7]))
# Out:
# [ -303106.31625261   -45877.11184568  -417092.84937083 -1991042.9427915
#   -180968.58751426   -73723.70170233   -75613.47003743    54059.34525946
#  -1109108.88900342  -357535.75246943   -51546.88599192   -46959.13239005
#   -527621.41423669   -24816.63549633   -24273.50864712   -17008.61344124
#     58815.68860953   -22938.55592284   -91754.22369135]
# [  49223.23590565  434743.49626255 1942225.33199465   69859.0235706
#    73161.67606762  209055.85194052   55508.05982328   50503.17476997
#   560119.40664677   25764.0337276   -98446.4718113   -11872.82671644]
# [ -4.27573148 -28.24940728  -3.10722473  -0.65091575  -7.16147059
#  -17.57916637 -17.13981936]
# [26.32905362  2.98107097  0.66727645 18.55166521 17.71420896  6.1993061
#  23.34798264]

# %%
#'''
t_init = np.zeros(len(s))

i_j = np.zeros(len(s))
O_j = np.zeros(len(s))
e_j = np.zeros(len(s))
o_j = np.zeros(len(s))

i_s = np.zeros(len(s))
O_s = np.zeros(len(s))
e_s = np.zeros(len(s))
o_s = np.zeros(len(s))

i_u = np.zeros(len(s))
O_u = np.zeros(len(s))
e_u = np.zeros(len(s))
o_u = np.zeros(len(s))

i_n = np.zeros(len(s))
O_n = np.zeros(len(s))
e_n = np.zeros(len(s))
o_n = np.zeros(len(s))

i_v = np.zeros(len(s))
O_v = np.zeros(len(s))
e_v = np.zeros(len(s))
o_v = np.zeros(len(s))

i_e = np.zeros(len(s))
O_e = np.zeros(len(s))
e_e = np.zeros(len(s))
o_e = np.zeros(len(s))

i_m = np.zeros(len(s))
O_m = np.zeros(len(s))
e_m = np.zeros(len(s))
o_m = np.zeros(len(s))

for i in range(len(s)):
    i_j[i] = s[i].particles[4].inc
    O_j[i] = s[i].particles[4].Omega
    e_j[i] = s[i].particles[4].e
    o_j[i] = s[i].particles[4].omega

    i_s[i] = s[i].particles[5].inc
    O_s[i] = s[i].particles[5].Omega
    e_s[i] = s[i].particles[5].e
    o_s[i] = s[i].particles[5].omega
    
    i_u[i] = s[i].particles[6].inc
    O_u[i] = s[i].particles[6].Omega
    e_u[i] = s[i].particles[6].e
    o_u[i] = s[i].particles[6].omega
    
    i_n[i] = s[i].particles[7].inc
    O_n[i] = s[i].particles[7].Omega
    e_n[i] = s[i].particles[7].e
    o_n[i] = s[i].particles[7].omega
    
    i_v[i] = s[i].particles[1].inc
    O_v[i] = s[i].particles[1].Omega
    e_v[i] = s[i].particles[1].e
    o_v[i] = s[i].particles[1].omega
    
    i_e[i] = s[i].particles[2].inc
    O_e[i] = s[i].particles[2].Omega
    e_e[i] = s[i].particles[2].e
    o_e[i] = s[i].particles[2].omega
    
    i_m[i] = s[i].particles[3].inc
    O_m[i] = s[i].particles[3].Omega
    e_m[i] = s[i].particles[3].e
    o_m[i] = s[i].particles[3].omega
    
    t_init[i] = s[i].t

ps = np.sin(i_s)*np.sin(O_s)
qs = np.sin(i_s)*np.cos(O_s)
pj = np.sin(i_j)*np.sin(O_j)
qj = np.sin(i_j)*np.cos(O_j)
pu = np.sin(i_u)*np.sin(O_u)
qu = np.sin(i_u)*np.cos(O_u)
pn = np.sin(i_n)*np.sin(O_n)
qn = np.sin(i_n)*np.cos(O_n)

pv = np.sin(i_v)*np.sin(O_v)
qv = np.sin(i_v)*np.cos(O_v)
pe = np.sin(i_e)*np.sin(O_e)
qe = np.sin(i_e)*np.cos(O_e)
pm = np.sin(i_m)*np.sin(O_m)
qm = np.sin(i_m)*np.cos(O_m)

hj = e_j*np.sin(o_j+O_j)
kj = e_j*np.cos(o_j+O_j)
hs = e_s*np.sin(o_s+O_s)
ks = e_s*np.cos(o_s+O_s)
hu = e_u*np.sin(o_u+O_u)
ku = e_u*np.cos(o_u+O_u)
hn = e_n*np.sin(o_n+O_n)
kn = e_n*np.cos(o_n+O_n)

hv = e_j*np.sin(o_v+O_v)
kv = e_j*np.cos(o_v+O_v)
he = e_j*np.sin(o_e+O_e)
ke = e_j*np.cos(o_e+O_e)
hm = e_j*np.sin(o_m+O_m)
km = e_j*np.cos(o_m+O_m)

hkj = kj+1j*hj
hks = ks+1j*hs
hku = ku+1j*hu
hkn = kn+1j*hn

hkv = kv+1j*hv
hke = ke+1j*he
hkm = km+1j*hm

pqs = qs+1j*ps
pqj = qj+1j*pj
pqu = qu+1j*pu
pqn = qn+1j*pn

pqv = qv+1j*pv
pqe = qe+1j*pe
pqm = qm+1j*pm
#plt.plot(i_s*180/np.pi)

freq_s = np.fft.fftfreq(len(pqs),1000)

# %%
print(g[0])
print(1/np.array(s_freq))
print(2*np.pi*206265*np.array(s_arr))
# Out:
# -8.490167819747786e-05
# [ 17432.04224566   8716.02112283 -11778.33019595  -5889.16509797
#   -7029.02196709  -4402.00943574  -5009.19366428  -3514.51098355
#  -36316.025251  ]
# [  26.32905154    2.98107078    0.66727693   18.55168822   17.71421818
#     6.19928462   23.34798077   25.66177462    2.31379385   50.30272604
#  -109.1569146    -4.27573125  -28.24940575   -3.10722427   -0.65091143]

# %%
fig,ax = plt.subplots(4,2,figsize=(11,12),sharex=True,sharey=True)
fig.subplots_adjust(hspace=0.15,wspace=0,top=0.935,left=0.05,bottom=0.05)
ax = ax.flatten()

ax[0].scatter(1/freq_s,np.abs(np.fft.fft(pqj))**2/np.max(np.abs(np.fft.fft(pqj))**2),s=5)
ax[1].scatter(1/freq_s,np.abs(np.fft.fft(pqs))**2/np.max(np.abs(np.fft.fft(pqs))**2),s=5)
ax[2].scatter(1/freq_s,np.abs(np.fft.fft(pqu))**2/np.max(np.abs(np.fft.fft(pqu))**2),s=5)
ax[3].scatter(1/freq_s,np.abs(np.fft.fft(pqn))**2/np.max(np.abs(np.fft.fft(pqn))**2),s=5)
ax[4].scatter(1/freq_s,np.abs(np.fft.fft(pqv))**2/np.max(np.abs(np.fft.fft(pqv))**2),s=5)
ax[5].scatter(1/freq_s,np.abs(np.fft.fft(pqe))**2/np.max(np.abs(np.fft.fft(pqe))**2),s=5)
ax[6].scatter(1/freq_s,np.abs(np.fft.fft(pqm))**2/np.max(np.abs(np.fft.fft(pqm))**2),s=5)
ax[7].scatter(1/freq_s,np.abs(np.fft.fft(pq_arr))**2/np.max(np.abs(np.fft.fft(pq_arr))**2),s=5)

ax[0].vlines(abs(1/s_arr[0]),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],label=r'No $s$ frequency',alpha=0)
ax[1].vlines(abs(1/s_arr[0]),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],label=r'$s_6 = -26.329$"/yr')
ax[2].vlines(abs(1/s_arr[1]),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],label=r'$s_7 = -2.981$"/yr')
ax[3].vlines(abs(1/s_arr[2]),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],label=r'$s_8 = -0.667$"/yr')
ax[4].vlines(abs(1/s_arr[5]),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],label=r'$s_2 = -6.199$"/yr')
ax[5].vlines(abs(1/s_arr[3]),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],label=r'$s_3 = -18.552$"/yr')
ax[6].vlines(abs(1/s_arr[4]),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],label=r'$s_4 = -17.714$"/yr')

labels = ['Saturn','Uranus','Neptune','Venus','Earth','Mars']
colors = ['red','darkblue','blue','green','orange','grey']

s_arr_new = [s_arr[0],s_arr[1],s_arr[2],s_arr[5],s_arr[3],s_arr[4]]
for i in range(6):
    ax[7].vlines(abs(1/np.array(s_arr_new[i])),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],label=labels[i],colors=colors[i])

ax[0].legend(loc='upper left')
ax[1].legend(loc='upper left')
ax[2].legend(loc='upper left')
ax[3].legend(loc='upper left')
ax[4].legend(loc='upper left')
ax[5].legend(loc='upper left')
ax[6].legend(loc='upper left')
ax[7].legend(loc='upper left')

ax[0].set_xscale('log')
ax[0].set_yscale('log')
ax[0].set_title('Jupiter')
ax[1].set_title('Saturn')
ax[2].set_title('Uranus')
ax[3].set_title('Neptune')
ax[4].set_title('Venus')
ax[5].set_title('Earth')
ax[6].set_title('Mars')
ax[7].set_title('Asteroid 46')
fig.suptitle('Inclination Power Spectra',fontsize=17)
fig.supxlabel('Period (yrs)',fontsize=15)
fig.supylabel('Normalized Power',fontsize=15)
fig.tight_layout()

fig.subplots_adjust(wspace=0)

plt.savefig('planet_inc.pdf')
#ax[0].vlines(abs(1/g[0]),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])

plt.show()

# %%
fig,ax = plt.subplots(4,2,figsize=(11,12),sharex=True,sharey=True)
fig.subplots_adjust(hspace=0.15,wspace=0)
ax = ax.flatten()
print(2*np.pi*206265*np.array(g_arr))

ax[0].scatter(-1/freq_s,np.abs(np.fft.fft(hkj))**2/np.max(np.abs(np.fft.fft(hkj))**2),s=5)
ax[1].scatter(-1/freq_s,np.abs(np.fft.fft(hks))**2/np.max(np.abs(np.fft.fft(hks))**2),s=5)
ax[2].scatter(-1/freq_s,np.abs(np.fft.fft(hku))**2/np.max(np.abs(np.fft.fft(hku))**2),s=5)
ax[3].scatter(-1/freq_s,np.abs(np.fft.fft(hkn))**2/np.max(np.abs(np.fft.fft(hkn))**2),s=5)
ax[4].scatter(-1/freq_s,np.abs(np.fft.fft(hkv))**2/np.max(np.abs(np.fft.fft(hkv))**2),s=5)
ax[5].scatter(-1/freq_s,np.abs(np.fft.fft(hke))**2/np.max(np.abs(np.fft.fft(hke))**2),s=5)
ax[6].scatter(-1/freq_s,np.abs(np.fft.fft(hkm))**2/np.max(np.abs(np.fft.fft(hkm))**2),s=5)
ax[7].scatter(-1/freq_s,np.abs(np.fft.fft(hk_arr))**2/np.max(np.abs(np.fft.fft(hk_arr))**2),s=5)

ax[0].vlines(abs(1/g_arr[0]),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],label=r'$g_5 = 4.276$"/yr')
ax[1].vlines(abs(1/g_arr[1]),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],label=r'$g_6 = 28.249$"/yr')
ax[2].vlines(abs(1/g_arr[2]),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],label=r'$g_7 = 3.107$"/yr')
ax[3].vlines(abs(1/g_arr[3]),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],label=r'$g_8 = 0.651$"/yr')
ax[4].vlines(abs(1/g_arr[4]),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],label=r'$g_2 = 7.161$"/yr')
ax[5].vlines(abs(1/g_arr[5]),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],label=r'$g_3 = 17.579$"/yr')
ax[6].vlines(abs(1/g_arr[6]),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],label=r'$g_4 = 17.140$"/yr')

labels = ['Jupiter','Saturn','Uranus','Neptune','Venus','Earth','Mars']
colors = ['red','darkblue','blue','green','orange','grey','pink']

#s_arr_new = [s_arr[0],s_arr[1],s_arr[2],s_arr[5],s_arr[3],s_arr[4]]
for i in range(7):
    ax[7].vlines(abs(1/np.array(g_arr[i])),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],label=labels[i],colors=colors[i])

ax[0].legend(loc='upper left')
ax[1].legend(loc='upper left')
ax[2].legend(loc='upper left')
ax[3].legend(loc='upper left')
ax[4].legend(loc='upper left')
ax[5].legend(loc='upper left')
ax[6].legend(loc='upper left')
ax[7].legend(loc='upper left')

ax[0].set_xscale('log')
ax[0].set_yscale('log')
ax[0].set_title('Jupiter')
ax[1].set_title('Saturn')
ax[2].set_title('Uranus')
ax[3].set_title('Neptune')
ax[4].set_title('Venus')
ax[5].set_title('Earth')
ax[6].set_title('Mars')
ax[7].set_title('Asteroid 46')


fig.suptitle('Eccentricity Power Spectra',fontsize=17)
fig.supxlabel('Period (yrs)',fontsize=15)
fig.supylabel('Normalized Power',fontsize=15)
fig.tight_layout()

fig.subplots_adjust(wspace=0)
#fig.suptitle('Eccentricity of the Planets')

#ax[0].vlines(abs(1/g[0]),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
plt.savefig('planet_ecc.pdf')
plt.show()
# Out:
# [ -4.27573125 -28.24940575  -3.10722427  -0.65091143  -7.16144829
#  -17.57913218 -17.13984839  23.9736745   -1.16850699  -3.62481982
#  -25.14218149 -27.59849432  -2.45631283 -52.22308025 -53.39158724
#  -76.19675475  22.03495722 -56.49881151]

# %%
'''
plt.scatter(1/freq_s,np.abs(np.fft.fft(hku))**2,s=2)
plt.xscale('log')
plt.yscale('log')
plt.show()
plt.scatter(1/np.flip(freq_s),np.abs(np.fft.fft(hku))**2,s=2)
plt.xscale('log')
plt.yscale('log')
plt.show()
'''
# Out:
# "\nplt.scatter(1/freq_s,np.abs(np.fft.fft(hku))**2,s=2)\nplt.xscale('log')\nplt.yscale('log')\nplt.show()\nplt.scatter(1/np.flip(freq_s),np.abs(np.fft.fft(hku))**2,s=2)\nplt.xscale('log')\nplt.yscale('log')\nplt.show()\n"

# %%
print(-1/np.array(g_arr))
print(-np.array(g_arr))
print(-2*np.pi*206265*np.array(g_arr))
# Out:
# [ 303106.33202781   45877.11432427  417092.9118434  1991056.15555523
#   180969.15109111   73723.84508116   75613.3419545   -54059.34819922
#  1109108.65847705  357535.34836158   51546.88816684   46959.12763724
#   527620.58636504   24816.63684112   24273.50982327   17008.61436395
#   -58815.69019882   22938.55716213]
# [ 3.29917225e-06  2.17973605e-05  2.39754734e-06  5.02246005e-07
#   5.52580367e-06  1.35641325e-05  1.32251792e-05 -1.84981883e-05
#   9.01624915e-07  2.79692625e-06  1.93998132e-05  2.12951145e-05
#   1.89530133e-06  4.02955488e-05  4.11971737e-05  5.87937370e-05
#  -1.70022658e-05  4.35947210e-05]
# [  4.27573125  28.24940575   3.10722427   0.65091143   7.16144829
#   17.57913218  17.13984839 -23.9736745    1.16850699   3.62481982
#   25.14218149  27.59849432   2.45631283  52.22308025  53.39158724
#   76.19675475 -22.03495722  56.49881151]

# %%
print(-1/np.array(s_arr))
print(-np.array(s_arr))
print(-2*np.pi*206265*np.array(s_arr))
# Out:
# [  -49223.23978281  -434743.52505361 -1942223.93551079   -69858.93692602
#    -73161.6379543   -209056.57629637   -55508.06428437   -50503.17979561
#   -560119.57058293   -25764.03545751    11872.82749959   303106.33202781
#     45877.11432427   417092.9118434   1991056.15555523]
# [-2.03156071e-05 -2.30020677e-06 -5.14873688e-07 -1.43145608e-05
#  -1.36683654e-05 -4.78339413e-06 -1.80154003e-05 -1.98007334e-05
#  -1.78533308e-06 -3.88137954e-05  8.42259352e-05  3.29917225e-06
#   2.17973605e-05  2.39754734e-06  5.02246005e-07]
# [-26.32905154  -2.98107078  -0.66727693 -18.55168822 -17.71421818
#   -6.19928462 -23.34798077 -25.66177462  -2.31379385 -50.30272604
#  109.1569146    4.27573125  28.24940575   3.10722427   0.65091143]

# %%
print(g)
print(1/g)
print(2*np.pi*206265*g)
print(2*np.pi*206265*s_freq)
# Out:
# [-8.49016782e-05 -1.69803356e-04 -1.42267303e-04 -2.27168981e-04
#  -1.99632928e-04 -2.84534607e-04 -2.75360531e-05]
# [-11778.33019595  -5889.16509797  -7029.02196709  -4402.00943574
#   -5009.19366428  -3514.51098355 -36316.025251  ]
# [-110.0326783  -220.0653566  -184.37859825 -294.41127656 -258.7245182
#  -368.75719651  -35.68675835]
# [  74.34591995  148.6918399  -110.0326783  -220.0653566  -184.37859825
#  -294.41127656 -258.7245182  -368.75719651  -35.68675835]

# %%
def find_local_max_windowed(freqs, powers, window_half_dex=0.05, window_protect_dex=0.1):
    """
    Identify local max frequency in windowed summed power spectrum, split separately
    for positive and negative frequencies.
    """
    # Separate positive and negative frequencies
    pos_mask = freqs > 0
    neg_mask = freqs < 0

    freqs_pos = freqs[pos_mask]
    powers_pos = powers[pos_mask]
    freqs_neg = freqs[neg_mask]
    powers_neg = powers[neg_mask]

    # Sort and log-transform positive frequencies
    logf_pos = np.log10(freqs_pos)
    sort_idx_pos = np.argsort(logf_pos)
    logf_pos = logf_pos[sort_idx_pos]
    powers_pos = powers_pos[sort_idx_pos]
    freqs_pos = freqs_pos[sort_idx_pos]

    # Sort and log-transform negative frequencies
    logf_neg = np.log10(-freqs_neg)
    sort_idx_neg = np.argsort(logf_neg)
    logf_neg = logf_neg[sort_idx_neg]
    powers_neg = powers_neg[sort_idx_neg]
    freqs_neg = freqs_neg[sort_idx_neg]

    # Cumulative sums
    cumsum_pos = np.cumsum(powers_pos)
    cumsum_neg = np.cumsum(powers_neg)

    # Initialize local power arrays
    local_power_pos = np.zeros_like(powers_pos)
    local_power_neg = np.zeros_like(powers_neg)

    # Compute windowed sums for positive
    for i in range(len(logf_pos)):
        center = logf_pos[i]
        min_logf = center - window_half_dex
        max_logf = center + window_half_dex

        left = np.searchsorted(logf_pos, min_logf, side='left')
        right = np.searchsorted(logf_pos, max_logf, side='right') - 1

        if left == 0:
            local_power_pos[i] = cumsum_pos[right]
        else:
            local_power_pos[i] = cumsum_pos[right] - cumsum_pos[left - 1]

    # Compute windowed sums for negative
    for i in range(len(logf_neg)):
        center = logf_neg[i]
        min_logf = center - window_half_dex
        max_logf = center + window_half_dex

        left = np.searchsorted(logf_neg, min_logf, side='left')
        right = np.searchsorted(logf_neg, max_logf, side='right') - 1

        if left == 0:
            local_power_neg[i] = cumsum_neg[right]
        else:
            local_power_neg[i] = cumsum_neg[right] - cumsum_neg[left - 1]

    # Recombine into full array
    local_power_all = np.zeros_like(freqs)
    unsort_idx_pos = np.argsort(sort_idx_pos)
    unsort_idx_neg = np.argsort(sort_idx_neg)
    local_power_all[pos_mask] = local_power_pos[unsort_idx_pos]
    local_power_all[neg_mask] = local_power_neg[unsort_idx_neg]

    # Find global maximum
    max_idx = np.argmax(local_power_all)
    max_freq = freqs[max_idx]
    #dominant_freq = freqs[max_idx]

    #if dominant_freq < 0:
    #    in_window = np.where((np.log10(-freqs) >= min_logf) & (np.log10(-freqs) <= max_logf))[0]
    #else:
    #    in_window = np.where((np.log10(freqs) >= min_logf) & (np.log10(freqs) <= max_logf))[0]
        
    #plt.plot(-1/freqs,local_power_all)
    #plt.vlines(abs(1/dominant_freq),ymin=1e-3,ymax=1e7)
    #plt.vlines(abs(1/max_freq),ymin=1e-3,ymax=1e7)
    #plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=1e-3,ymax=1e7,colors='r')
    #plt.yscale('log')
    #plt.xscale('log')
    #plt.xlim(abs(0.5/freqs[np.min(in_window)]),abs(2/freqs[np.max(in_window)]))
    #plt.ylim(5e6,8e6)
    #plt.show()

    min_logf = np.log10(abs(max_freq)) - window_half_dex
    max_logf = np.log10(abs(max_freq)) + window_half_dex

    ind_low = np.argmin(abs(freqs-10**min_logf))
    ind_high = np.argmin(abs(freqs-10**max_logf))

    if max_freq < 0:
        ind_high = np.argmin(abs(freqs+10**min_logf))
        ind_low = np.argmin(abs(freqs+10**max_logf))

    #max_idx = np.argmax(powers[ind_low:ind_high])+ind_low
    print(max_freq,max_freq*2*np.pi*206265)
    dominant_freq = np.sum(freqs[ind_low:ind_high]*(powers[ind_low:ind_high]))/np.sum((powers[ind_low:ind_high]))
    print(dominant_freq,dominant_freq*2*np.pi*206265)
    max_idx = np.argmin(np.abs(freqs-dominant_freq))
    
    #min_logf = np.log10(abs(dominant_freq)) - window_protect_dex
    #max_logf = np.log10(abs(dominant_freq)) + window_protect_dex

    if dominant_freq < 0:
        in_window = np.where((np.log10(-freqs) >= min_logf) & (np.log10(-freqs) <= max_logf))[0]
    else:
        in_window = np.where((np.log10(freqs) >= min_logf) & (np.log10(freqs) <= max_logf))[0]
                
    #protect_bins = round((np.max(in_window)-np.min(in_window))/2)
    '''
    protect_bins = 10
    plt.plot(-1/freqs,local_power_all)
    plt.vlines(abs(1/dominant_freq),ymin=1e-3,ymax=1e7)
    plt.vlines(abs(1/max_freq),ymin=1e-3,ymax=1e7)
    #plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=1e-3,ymax=1e7,colors='r')
    plt.yscale('log')
    plt.xscale('log')
    plt.xlim(abs(0.5/freqs[np.min(in_window)]),abs(2/freqs[np.max(in_window)]))
    #plt.xlim(2e4,2e5)
    #plt.ylim(5e6,8e6)
    plt.show()
    plt.plot(-1/freqs,powers)
    plt.vlines(abs(1/dominant_freq),ymin=1e-3,ymax=1e7)
    plt.vlines(abs(1/max_freq),ymin=1e-3,ymax=1e7)
    #plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=1e-3,ymax=1e7,colors='r')
    plt.xlim(abs(0.5/freqs[np.min(in_window)]),abs(2/freqs[np.max(in_window)]))
    plt.yscale('log')
    plt.xscale('log')
    #plt.xlim(2e4,2e5)
    plt.show()
    '''
    plt.plot(-1/freqs,local_power_all)
    #plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='r')
    plt.yscale('log')
    plt.xscale('log')
    plt.xlim(0.7*abs(1/freqs[np.min(in_window)]),1.8*abs(1/freqs[np.max(in_window)]))
    #plt.xlim(0.5*abs(1/freqs[np.min(in_window)]),1.1*abs(2/freqs[np.max(in_window)]))
    #plt.ylim(1e3,6e7)
    plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='r')
    plt.vlines(abs(1/dominant_freq),ymin=plt.ylim()[0],ymax=plt.ylim()[1])
    plt.vlines(abs(1/max_freq),ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='g')
    plt.vlines(abs(1/2.022e-5),ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='k')
    plt.show()
    #'''
    plt.plot(-1/freqs,powers)
    plt.yscale('log')
    plt.xscale('log')
    plt.xlim(0.7*abs(1/freqs[np.min(in_window)]),1.8*abs(1/freqs[np.max(in_window)]))
    #plt.xlim(0.5*abs(1/freqs[np.min(in_window)]),1.1*abs(2/freqs[np.max(in_window)]))
    #plt.ylim(2e3,6e7)
    plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='r')
    plt.vlines(abs(1/dominant_freq),ymin=plt.ylim()[0],ymax=plt.ylim()[1])
    plt.vlines(abs(1/max_freq),ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='g')
    plt.show()
    #'''
    protect_bins = 10

    return max_idx, dominant_freq, local_power_all, protect_bins
    
#powers = np.abs(np.fft.fft(hkj))**2
#freq = np.fft.fftfreq(len(powers),1000)

#good_freq_inds = np.where(abs(1/freq) <= abs(t_init[-1]))[0]
#bad_freq_inds = np.where(abs(1/freq) > abs(t_init[-1]))[0]
#powers[bad_freq_inds] = 0
#powers[~good_freq_inds] = 0


#max_idx, g5, local_power_all, protect_bins = find_local_max_windowed(freq, powers, window_half_dex=0.02, window_protect_dex=0.15)

# %%
print(1/np.array(g_arr))
print(g_arr)
print(2*np.pi*206265*np.array(g_arr))

print(1/np.array(s_arr))
print(s_arr)
print(2*np.pi*206265*np.array(s_arr))
# Out:
# [ -303066.66727252   -45877.0643119   -416716.66749972 -2000240.00399866
#   -181840.00036351   -73538.23544113   -75766.66681813   -24816.87349874
#    -24274.75733008   -17008.84357142   -47852.63167461   -44058.14986781
#    -15900.1590143    -46953.99070419    65797.36855259]
# [-3.299604040918085e-06, -2.179738427030735e-05, -2.3997120297586074e-06, -4.999400061997099e-07, -5.499340068196808e-06, -1.3598368168632107e-05, -1.319841616367234e-05, -4.029516449969662e-05, -4.1195056510856095e-05, -5.8792944729085884e-05, -2.0897492259147876e-05, -2.2697276281466827e-05, -6.28924527799235e-05, -2.129744426410764e-05, 1.519817618847118e-05]
# [ -4.27629085 -28.24943655  -3.11002971  -0.64792286  -7.12715142
#  -17.6235017  -17.10516342 -52.22258225 -53.38884339 -76.19572794
#  -27.08317541 -29.41569769 -81.50869537 -27.60151369  19.69685484]
# [  49266.99517238  434834.78347797 2000240.00399866   69938.46167827
#    73001.45999995  208358.33374986  -24816.87349874  -24274.75733008
# ...

# %%
print(1/g,1/s_freq)
# Out:
# [-40681.13638731 -20340.56819365 -19926.21183337 -13374.96137142
#  -13194.54614857 978168.81671577] [ 39056.80019068  19528.40009534 -19926.21183337 -13374.96137142
#  -13194.54614857 978168.81671577]

# %%
print(1/np.array(s_arr))

new = s_arr.copy()
new.append(s_freq-s_arr[0])
new.append(s_freq-s_arr[1])
new.append(s_freq-s_arr[2])
new.append(-2*s_freq-s_arr[0])
print(new)
#print(1/np.array(new))
# Out:
# [  49266.99517238  434834.78347797 2000240.00399866   69938.46167827
#    73001.45999995  208358.33374986  -24816.87349874  -24274.75733008
#   -17008.84357142  -47852.63167461  -44058.14986781  -15900.1590143
#   -46953.99070419   65797.36855259]
# [2.029756425170822e-05, 2.2997240285186655e-06, 4.999400061997099e-07, 1.4298284177311702e-05, 1.369835616987205e-05, 4.799424059517215e-06, -4.029516449969662e-05, -4.1195056510856095e-05, -5.8792944729085884e-05, -2.0897492259147876e-05, -2.2697276281466827e-05, -6.28924527799235e-05, -2.129744426410764e-05, 1.519817618847118e-05, array([ 5.30617172e-06,  3.09099077e-05, -7.04827178e-05, -9.50641353e-05,
#        -9.60864537e-05, -1.92752458e-05]), array([ 2.33040119e-05,  4.89077479e-05, -5.24848776e-05, -7.70662951e-05,
#        -7.80886135e-05, -1.27740561e-06]), array([ 2.51037960e-05,  5.07075319e-05, -5.06850935e-05, -7.52665111e-05,
# ...

# %%
print(1/np.array(g_arr))
print(1/g)
print(s[-1].t)
# Out:
# [ -303106.33202781   -45877.11432427  -417092.9118434  -1991056.15555523
#   -180969.15109111   -73723.84508116   -75613.3419545     54059.34819922
#  -1109108.65847705  -357535.34836158   -51546.88816684   -46959.12763724
#   -527620.58636504   -24816.63684112   -24273.50982327   -17008.61436395
#     58815.69019882   -22938.55716213]
# [-11778.33019595  -5889.16509797  -3926.11006532  -7029.02196709
#   -4402.00943574  -5009.19366428  -3514.51098355 -36316.025251  ]
# -10000000.0

# %%
1/1000.02/10000
print(np.fft.fftfreq(len(hk_arr),100.0199))
# Out:
# [ 0.00000000e+00  9.99701069e-07  1.99940214e-06 ... -2.99910321e-06
#  -1.99940214e-06 -9.99701069e-07]

# %%
print(1/(3*g_arr[1]-3*s_arr[0]))
print(1/(2*g_arr[1]-2*s_arr[0]))
print(1/(2*g_arr[1]-3*s_arr[0]))
print(1/(2*g_arr[1]-3*s_arr[0]))
print(1/(s_freq*2))
print(1/(g*4))
# Out:
# -7915.217638911312
# -11872.82645836697
# -9565.574540732208
# -9565.574540732208
# [   9773.82144465    4886.91072233    3257.94048155   -4689.24941691
#    -3084.57886752   -3168.89040709   -2344.62470845 -115935.40377978]
# [ -4506.95616664  -2253.47808332  -1502.31872221  -2344.62470845
#   -1542.28943376  -1584.44520355  -1172.31235423 -57967.70188989]

# %%
hk = hk_arr
pq = pq_arr

hkn = hk_new
pqn = pq_new
'''
hk = k+1j*h
pq = q+1j*p

hkn = np.fft.ifft(Yhk_f)
pqn = np.fft.ifft(Ypq_f)

hk_new = hkn
pq_new = pq
'''
t = np.linspace(0,1e7,len(hk))

fig,ax=plt.subplots(2,figsize=(6,6),sharex=True)
fig.subplots_adjust(hspace=0,wspace=0.025)
ax[0].plot(t,np.abs(hk),alpha=0.5)
ax[0].plot(t,np.abs(hkn),alpha=0.5)
ax[0].plot(t,np.ones(len(hkn))*np.mean((np.abs(hkn))))
y0,y1 = ax[0].get_ylim()
ax[0].vlines([0.05*t[-1],0.95*t[-1]],ymin=y0,ymax=y1,colors='k')
ax[0].set_ylim(y0,y1)
#ax[0].set_title('Eccentricity')
#plt.xlim(1000,10000)
#plt.ylim(0,1)
#ax[0].set_xlabel('Time(yrs)')
#ax[0].set_xlabel('Time(yrs)')
fig.supxlabel('Time(yrs)',y=0.025)
#plt.show()
#ax[1].plot(t,np.arcsin(np.abs(pq))*180/np.pi)
#ax[1].plot(t,np.arcsin(np.abs(pqn))*180/np.pi)
ax[1].plot(t,(np.abs(pq)),alpha=0.5)
ax[1].plot(t,(np.abs(pqn)),alpha=0.5)
ax[1].plot(t,np.ones(len(pqn))*np.mean((np.abs(pqn))))

y2,y3 = ax[1].get_ylim()
ax[1].vlines([0.05*t[-1],0.95*t[-1]],ymin=y2,ymax=y3,colors='k')
ax[1].set_ylim(y2,y3)
#ax[1].set_title('Inclination (deg)')
ax[1].set_ylabel('Inc (deg)',fontsize=12)
#ax[1].yaxis.set_label_position("")

# Move the y-axis ticks to the right
#ax[1].yaxis.tick_right()
ax[0].set_ylabel('Ecc',fontsize=12)
fig.suptitle('Asteroid ('+str(objname)+') Proserpina',fontsize=14,x=0.52,y=0.94)
#ax[0].set_xlim(-3e5,1e8+3e5)
#ax[1].set_xlim(-3e5,1e8+3e5)
#fig.tight_layout()
plt.savefig('../data/results/eccandinc.pdf')
plt.show()

print(pes)
#'''
print(pes)
print(error_list)
print('std',np.std(error_list,axis=0))
print('rms',np.sqrt(np.nanmean((np.array(error_list)-np.array(pes))**2,axis=0)))
print('outrms',rms)
errs = np.std(error_list,axis=0)

def hcm(a,rms_a,rms_e,rms_i):
    F = 365*24*60*60/1.496e11
    return (2*np.pi*1/F*np.sqrt((5/4*(rms_a/a)**2+2*rms_e**2+2*rms_i**2)/a))

print(hcm(pes[0],errs[0],errs[1],errs[2]))
print(hcm(pes[0],*np.sqrt(np.nanmean((np.array(error_list)-np.array(pes))**2,axis=0))))
print(hcm(pes[0],*np.std(error_list,axis=0)))
#df = pd.read_csv('../data/results/NesvornyAst_prop_elem_multi_5win_helio_1000.csv')
#num = 12
#print(hcm(df['PropSMA'].iloc[num],df['RMS_err_a'].iloc[num],df['RMS_err_e'].i?loc[num],df['RMS_err_sinI'].iloc[num]))
#print(df.iloc[num])
#'''

print(np.mean(np.abs(pq)),np.mean(np.abs(pq)*180/np.pi))
print(np.mean(np.abs(pq_new)),np.mean(np.abs(pq_new)*180/np.pi))
N = len(pq)
print(np.mean(np.abs(pq_new[int(0.05*N):int(0.95*N)])),np.mean(np.abs(pq_new[int(0.05*N):int(0.95*N)])*180/np.pi))
# Out:
# [3.19482037 0.01439324 0.29614238]
# [3.19482037 0.01439324 0.29614238]
# [[3.19481393 0.01439978 0.29614928]
#  [3.19482071 0.01440037 0.29614342]
#  [3.19484368 0.01440618 0.29614555]
#  [3.19483495 0.0144094  0.29614818]
#  [3.19480489 0.014399   0.29614654]]
# std [1.40280077e-05 4.10905766e-06 2.04489615e-06]
# rms [1.44033677e-05 1.05398457e-05 4.67929685e-06]
# outrms [1.44033677e-05 1.05398457e-05 4.67929685e-06]
# 0.1357106189088676
# 0.2846476930437664
# 0.1357106189088676
# 0.296825407579768 17.00684310657118
# 0.2961426683532592 16.9677250303842
# 0.29614455220805735 16.967832967313353

# %%
fig,ax=plt.subplots(2,figsize=(6,6),sharex=True)
fig.subplots_adjust(hspace=0,wspace=0.025)
#ax[0].plot(t,np.abs(hk),alpha=0.5)
ax[0].plot(t,np.abs(hkn),alpha=0.5)
ax[0].plot(t,np.ones(len(hkn))*np.mean((np.abs(hkn))))
y0,y1 = ax[0].get_ylim()
#ax[0].vlines([0.05*t[-1],0.95*t[-1]],ymin=y0,ymax=y1,colors='k')
ax[0].set_xlim(0.05*t[-1]-5000,0.05*t[-1]+5000)
ax[1].set_xlim(0.95*t[-1]-5000,0.95*t[-1]+5000)
#ax[0].set_title('Eccentricity')
#plt.xlim(1000,10000)
#plt.ylim(0,1)
#ax[0].set_xlabel('Time(yrs)')
#ax[0].set_xlabel('Time(yrs)')
fig.supxlabel('Time(yrs)',y=0.025)
#ax[1].plot(t,np.abs(hk),alpha=0.5)
ax[1].plot(t,np.abs(hkn),alpha=0.5)
ax[1].plot(t,np.ones(len(hkn))*np.mean((np.abs(hkn))))
y0,y1 = ax[0].get_ylim()
#ax[0].vlines([0.05*t[-1],0.95*t[-1]],ymin=y0,ymax=y1,colors='k')
#ax[1].set_xlim(0.05*t[-1]-5000,0.05*t[-1]+5000)
#ax[0].set_title('Eccentricity')
#plt.xlim(1000,10000)
#plt.ylim(0,1)
#ax[0].set_xlabel('Time(yrs)')
#ax[0].set_xlabel('Time(yrs)')

fig.supxlabel('Time(yrs)',y=0.025)
#plt.show()
plt.show()
#ax[1].plot(t,np.arcsin(np.abs(pq))*180/np.pi)
#ax[1].plot(t,np.arcsin(np.abs(pqn))*180/np.pi)
fig,ax=plt.subplots(2,figsize=(6,6),sharex=True)
fig.subplots_adjust(hspace=0,wspace=0.025)
#ax[0].plot(t,(np.abs(pq)),alpha=0.5)
ax[0].plot(t,(np.abs(pqn)),alpha=0.5)
ax[0].plot(t,np.ones(len(pqn))*np.mean((np.abs(pqn))))

#ax[1].plot(t,(np.abs(pq)),alpha=0.5)
ax[1].plot(t,(np.abs(pqn)),alpha=0.5)
ax[1].plot(t,np.ones(len(pqn))*np.mean((np.abs(pqn))))

y2,y3 = ax[1].get_ylim()
ax[1].set_ylim(y2,y3)
#ax[1].set_title('Inclination (deg)')
ax[1].set_ylabel('Inc (deg)',fontsize=12)
ax[0].set_xlim(0.05*t[-1]-5000,0.05*t[-1]+5000)
ax[1].set_xlim(0.95*t[-1]-5000,0.95*t[-1]+5000)
#ax[1].yaxis.set_label_position("")

# Move the y-axis ticks to the right
#ax[1].yaxis.tick_right()
ax[0].set_ylabel('Ecc',fontsize=12)
fig.suptitle('Asteroid ('+str(objname)+') Proserpina',fontsize=14,x=0.52,y=0.94)
#ax[0].set_xlim(-3e5,1e8+3e5)
#ax[1].set_xlim(-3e5,1e8+3e5)
#fig.tight_layout()
#plt.savefig('../data/results/eccandinc.pdf')
plt.show()

# %%
print('g arc/year', g*2*np.pi*206265)
print('s arc/year', s_freq*2*np.pi*206265)

print('g arc/year',1/(68/2/np.pi/206265))
# Out:
# g arc/year [-19.79478871 -39.58957743 -57.42663979 -77.2214285  -95.05849086
#   17.83706236]
# s arc/year [ 37.63185107  75.26370214 -57.42663979 -77.2214285  -95.05849086
#   17.83706236]
# g arc/year 19058.841432138197

# %%
1/(1.51e22/2e20)

plt.plot(range(10001),np.kaiser(10001,5))
plt.show()


plt.plot(range(10001),np.abs(pq_new)*np.kaiser(10001,5))
plt.show()

# %%
#g_arr = freq1
#s_arr = freq2

#extras = np.array([g-s_freq,2*g-s_freq,g-2*s_freq,3*g-s_freq,g-3*s_freq,2*g-2*s_freq,3*g-3*s_freq,2*g-3*s_freq,3*g-2*s_freq,
#                  g+s_freq,2*g+s_freq,g+2*s_freq,3*g+s_freq,g+3*s_freq,2*g+2*s_freq,3*g+3*s_freq,2*g+3*s_freq,3*g+2*s_freq])

print('ecc')
fig,ax = plt.subplots(1,2,figsize=(10,3))
#dt = 10000
freq = np.fft.fftfreq(len(hk),dt)
freq_sig = np.fft.fftfreq(len(hk_sig),dt)
print(len(hk_sig),len(freq))
ax[0].scatter(1/np.flip(freq_sig),np.abs(hk_sig)**2,s=5)
ax[0].set_yscale('log')
ax[0].set_xscale('log')
#plt.show()
ax[1].scatter(1/np.flip(freq),np.abs(np.fft.fft(hk))**2,s=5)
ax[0].vlines(abs(1/np.array(g_arr)),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],alpha=0.3,label='Filtered Freqs')
ax[1].vlines(abs(1/g),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='r',label='Protected Freqs')
ax[1].vlines(abs(1/g[0]),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='g')
ax[1].set_yscale('log')
ax[1].set_xscale('log')
ax[0].set_title('Eccentricity Filtered')
ax[1].set_title('Eccentricity UnFiltered')
ax[0].set_xlabel('Period (yrs)')
ax[1].set_xlabel('Period (yrs)')
ax[0].set_ylabel('Power Spectrum')
ax[0].legend()
ax[1].legend()

ax[0].set_xlim(2e3,1e7)
ax[1].set_xlim(2e3,1e7)
plt.show()


fig,ax = plt.subplots(1,2,figsize=(10,3))
#dt = 10000
freq = np.fft.fftfreq(len(hk),dt)
freq_sig = np.fft.fftfreq(len(hk_sig),dt)
print(len(hk_sig),len(freq))
ax[0].scatter(-1/np.flip(freq_sig),np.abs(hk_sig)**2,s=5)
ax[0].set_yscale('log')
ax[0].set_xscale('log')
#plt.show()
ax[1].scatter(-1/np.flip(freq),np.abs(np.fft.fft(hk))**2,s=5)
ax[0].vlines(abs(1/np.array(g_arr)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],alpha=0.3)
ax[1].vlines(abs(1/g),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='r')
ax[1].set_yscale('log')
ax[1].set_xscale('log')

ax[0].set_xlim(2e3,1e8)
ax[1].set_xlim(2e3,1e8)
#ax[0].set_xlim(abs(1/g[0])-1e3,abs(1/g[0])+1e3)
#ax[1].set_xlim(abs(1/g[0])-1e3,abs(1/g[0])+1e3)
plt.show()

fig,ax = plt.subplots(1,2,figsize=(10,3))
#freq = np.fft.fftfreq(len(hk_new),dt)
ax[0].scatter(-1/(freq_sig),np.abs((hk_sig))**2,s=5)
ax[0].set_yscale('log')
ax[0].set_xscale('log')
#plt.show()
freq = np.fft.fftfreq(len(hk),dt)
#freq = np.arange(len(hk))
#freq = np.fft.fftfreq(len(hk_sig),dt)
ax[1].scatter(-1/(freq),np.abs(np.fft.fft(hk))**2,s=5)
ax[1].vlines(abs(1/g),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='r',alpha=0.3)
ax[0].vlines(abs(1/g),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='r',alpha=0.3)
ax[0].vlines(abs(1/np.array(g_arr)),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],alpha=0.3)
ax[1].vlines(abs(1/np.array(g_arr)),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],alpha=0.3)
#ax[1].vlines(abs(1/np.array(g_arr)),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1])
#ax[1].vlines(abs(1/g),ymin=ax[1].get_ylim()[0],colors='r',ymax=ax[1].get_ylim()[1])
ax[1].set_yscale('log')
ax[1].set_xscale('log')
ax[0].set_xlim(2e3,1e8)
ax[1].set_xlim(2e3,1e8)
ax[0].set_xlim(abs(1/g[0])-2e4,abs(1/g[0])+5e4)
ax[1].set_xlim(abs(1/g[0])-2e4,abs(1/g[0])+5e4)

ax[0].set_title('Eccentricity Filtered')
ax[1].set_title('Eccentricity UnFiltered')
ax[0].set_xlabel('Period (yrs)')
ax[1].set_xlabel('Period (yrs)')
ax[0].set_ylabel('Power Spectrum')
#ax[0].set_xlim(6.9e3,9.1e3)
#ax[1].set_xlim(6.9e3,9.1e3)

plt.show()

print('inc')
fig,ax = plt.subplots(1,2,figsize=(10,3))
freq = np.fft.fftfreq(len(pq_new),dt)
#freq = np.fft.fftfreq(len(hk_sig),dt)
ax[0].scatter(1/(freq_sig),np.abs((pq_sig))**2,s=2)
#ax[0].vlines(abs(1/np.array(s_arr)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].vlines(abs(1/s_freq),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],colors='r')
#ax[1].vlines(abs(1/s_freq),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='r')

#ax[0].vlines(abs(1/extras),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],colors='r')
#ax[1].vlines(abs(1/extras),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='r')
#ax[1].vlines(abs(1/np.array(s_arr)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(abs(-1/np.array(s_arr)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
ax[0].vlines(abs(1/np.array(s_arr)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],alpha=0.2,label='Filtered Freqs')
ax[1].vlines(abs(1/np.array(s_freq)),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],alpha=0.2,label='Protected Freqs')
#ax[1].vlines(49266,ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(abs(1/np.array(new)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(abs(-1/np.array(new)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].vlines(1/np.array(s_arr),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].vlines(1/(s_freq*2),ymin=1e-3,ymax=1e4,colors='g')
#ax[1].vlines(1/(s_freq*2),ymin=1e-3,ymax=1e4,colors='g')
ax[0].set_yscale('log')
ax[0].set_xscale('log')
#plt.show()
freq = np.fft.fftfreq(len(pq),dt)
ax[1].scatter(1/(freq),np.abs(np.fft.fft(pq))**2,s=2)
ax[1].vlines(abs(1/s_freq),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='r')
ax[1].set_yscale('log')
ax[1].set_xscale('log')


ax[0].set_title('Inclination Filtered')
ax[1].set_title('Inclination UnFiltered')
ax[0].set_xlabel('Period (yrs)')
ax[1].set_xlabel('Period (yrs)')
ax[0].set_ylabel('Power Spectrum')
ax[0].legend()
ax[1].legend()

plt.show()

fig,ax = plt.subplots(1,2,figsize=(10,3))
freq = np.fft.fftfreq(len(pq_new),dt)
#freq = np.fft.fftfreq(len(hk_sig),dt)
ax[0].scatter(1/(freq_sig),np.abs((pq_sig))**2,s=2)
#ax[0].vlines(abs(1/np.array(s_arr)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].vlines(abs(1/s_freq),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],colors='r')
#ax[1].vlines(abs(1/s_freq),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='r')

#ax[0].vlines(abs(1/extras),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],colors='r')
#ax[1].vlines(abs(1/extras),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='r')
ax[0].vlines(abs(1/np.array(s_arr)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],alpha=0.3)
ax[0].vlines(abs(1/np.array(s_freq)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],alpha=0.3,colors='r')
ax[1].vlines(abs(1/np.array(s_arr)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],alpha=0.3)
#ax[1].vlines(abs(-1/np.array(s_arr)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(49266,ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(abs(1/np.array(new)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(abs(-1/np.array(new)),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].vlines(1/s_freq,ymin=1e-3,ymax=1e4)
#ax[0].vlines(1/(s_freq*2),ymin=1e-3,ymax=1e4,colors='g')
#ax[1].vlines(1/(s_freq*2),ymin=1e-3,ymax=1e4,colors='g')
ax[0].set_yscale('log')
ax[0].set_xscale('log')
#plt.show()
freq = np.fft.fftfreq(len(pq),dt)
ax[1].scatter(1/(freq),np.abs(np.fft.fft(pq))**2,s=2)
ax[1].vlines(abs(1/s_freq),ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1],colors='r')
ax[1].set_yscale('log')
ax[1].set_xscale('log')
ax[0].set_xlim(abs(1/s_freq[0])-4e3,abs(1/s_freq[0])+5e4)
ax[1].set_xlim(abs(1/s_freq[0])-4e3,abs(1/s_freq[0])+5e4)
plt.show()

fig,ax = plt.subplots(1,2,figsize=(10,3))
#freq = np.fft.fftfreq(len(pq_new),dt)
#freq = np.fft.fftfreq(len(hk_sig),dt)
ax[0].scatter(1/np.flip(freq_sig),np.abs((pq_sig))**2,s=5)
ax[0].vlines(1/s_freq,ymin=1e-3,ymax=1e4,colors='r')
#ax[0].vlines(-1/(s_freq*2),ymin=1e-3,ymax=1e4,colors='g')
ax[0].set_yscale('log')
ax[0].set_xscale('log')
#plt.show()
freq = np.fft.fftfreq(len(pq),dt)
ax[1].scatter(1/np.flip(freq),np.abs(np.fft.fft(pq))**2,s=5)
#ax[1].vlines(49266,ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1])
#ax[0].vlines(49266,ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].vlines(-1/np.array(s_arr),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(-1/np.array(s_arr),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
ax[1].vlines(1/s_freq,ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1],colors='g')
#ax[1].vlines(1/s_ex,ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].set_xlim(6e3,2e4)
#ax[1].set_xlim(8e3,6e4)
ax[1].set_yscale('log')
ax[1].set_xscale('log')
plt.show()

half = int(N/2)

#print(1/extras)
# Out:
# ecc
# 10001 10001
# 10001 10001
# inc

# %%
print(45.386/2/np.pi/206265)
print(1/3.5e-5)
# Out:
# 3.502002883266072e-05
# 28571.428571428572

# %%
print(1/g[0])
print(1/s_freq)
# Out:
# -24601.092612596185
# [ 22677.27014531  11338.63507266 -11800.01993517  -7974.84919931
#   -7761.40581714 289988.10053078]

# %%
print(1/g)
print(1/np.array(g_arr))
print(1/s_freq)
print(1/np.array(s_arr))

print(1/s_freq)
# Out:
# [-11778.81213515  -5889.40606757  -7028.8836036   -4402.02248253
#   -5008.96596759  -3514.4418018  -36328.8862084 ]
# [ -303066.66727252   -45877.0643119   -416716.66749972 -2000240.00399866
#   -181840.00036351   -73538.23544113   -75766.66681813   -24816.87349874
#    -24274.75733008   -17008.84357142   -47852.63167461   -44058.14986781
#    -15900.1590143    -46953.99070419    65797.36855259]
# [ 17430.13582978   8715.06791489 -11778.81213515  -5889.40606757
#   -7028.8836036   -4402.02248253  -5008.96596759  -3514.4418018
#  -36328.8862084 ]
# [  49266.99517238  434834.78347797 2000240.00399866   69938.46167827
#    73001.45999995  208358.33374986  -24816.87349874  -24274.75733008
#   -17008.84357142  -47852.63167461  -44058.14986781  -15900.1590143
#   -46953.99070419   65797.36855259]
# [ 17430.13582978   8715.06791489 -11778.81213515  -5889.40606757
#   -7028.8836036   -4402.02248253  -5008.96596759  -3514.4418018
#  -36328.8862084 ]

# %%
pq_zp = hk.copy()
#pq_zp = hk_new.copy()
N = len(pq_zp)
goal = 2**15
pq_zp = np.append(pq_zp, np.zeros(goal-N))
print(pq_zp)

freqs = np.fft.fftfreq(len(pq_zp),1000)

window_dex = 0.25
n_bins = len(freqs)

local_power = np.zeros(n_bins)
window_half_dex = window_dex / 2

Ypq_zp = np.fft.fft(pq_zp)
powers = np.abs(Ypq_zp)**2
#tol_bins = abs(round(fbin_og/fbin))

fbin = 1/len(hk_arr)/dt
tol_bins = 2
dist = int(tol_bins*2)
for i in g_arr[:8]:
    ind = np.argmin(abs(freqs-i))
    powers[ind-dist:ind+dist+1] = powers[ind-dist:ind+dist+1]/5

n_bins = len(Ypq_zp)

for i in range(n_bins):
    if freqs[i] < 0:
        center_logf = np.log10(-freqs[i])
    else:
        center_logf = np.log10(freqs[i])
    # Define window boundaries
    min_logf = center_logf - window_half_dex
    max_logf = center_logf + window_half_dex
    # Find indices inside window
    if freqs[i] < 0:
        in_window = (np.log10(-freqs) >= min_logf) & (np.log10(-freqs) <= max_logf)
    else:
        in_window = (np.log10(freqs) >= min_logf) & (np.log10(freqs) <= max_logf)        
    # Sum power inside window
    local_power[i] = np.sum(powers[in_window])

# Find index of maximum integrated power
max_idx_1 = np.argmax(local_power)

dominant_freq = freqs[max_idx_1]
min_logf = np.log10(abs(dominant_freq)) - window_half_dex
max_logf = np.log10(abs(dominant_freq)) + window_half_dex

ind_low = np.argmin(abs(freqs-10**min_logf))
ind_high = np.argmin(abs(freqs-10**max_logf))

if dominant_freq < 0:
    ind_high = np.argmin(abs(freqs+10**min_logf))
    ind_low = np.argmin(abs(freqs+10**max_logf))

max_idx = np.argmax(powers[ind_low:ind_high])+ind_low
dominant_freq = freqs[max_idx]
min_logf = np.log10(abs(dominant_freq)) - window_half_dex
max_logf = np.log10(abs(dominant_freq)) + window_half_dex
dominant_power_sum = local_power[max_idx]

print(f"Dominant region center frequency: {dominant_freq:.6e} [1/yr]")
print(f"Approximate period: {1/dominant_freq:.1f} yr")
print(f"Total integrated power in this region: {dominant_power_sum:.2f}")



print(min_logf,max_logf)
plt.scatter(-1/freqs,powers,s=5)
plt.vlines(-1/dominant_freq,ymin=1e-3,ymax=1e5,colors='k')
plt.vlines(-(1/np.array(g_arr[:8])),ymin=1e-3,ymax=1e5,colors='g')
plt.vlines(1/np.array([10**min_logf,10**max_logf]),ymin=1e-3,ymax=1e3,colors='r')
plt.xscale('log')
plt.yscale('log')
plt.xlim(abs(1/dominant_freq)-5e4,abs(1/dominant_freq)+5e4)
plt.show()

plt.scatter(-1/freqs,np.abs(Ypq_zp)**2,s=5)
plt.vlines(abs(1/g[0]),ymin=1e-3,ymax=1e5,colors='k')
plt.vlines(-(1/np.array(g_arr[:8])),ymin=1e-3,ymax=1e5,colors='g')
plt.vlines(1/np.array([10**min_logf,10**max_logf]),ymin=1e-3,ymax=1e3,colors='r')
plt.xscale('log')
plt.yscale('log')
plt.xlim(abs(1/dominant_freq)-5e4,abs(1/dominant_freq)+5e4)
plt.show()

plt.scatter(1/freqs,powers,s=5)
plt.vlines(-1/dominant_freq,ymin=1e-3,ymax=1e3)
plt.xscale('log')
plt.yscale('log')
plt.xlim(2e4,6e4)
plt.show()

plt.plot(local_power)
# Out:
# [0.06435056+0.0443147j  0.06993003+0.0303781j  0.07907381+0.01155213j ...
#  0.        +0.j         0.        +0.j         0.        +0.j        ]
# Dominant region center frequency: -5.548096e-05 [1/yr]
# Approximate period: -18024.2 yr
# Total integrated power in this region: 695478.93
# -4.380856056073769 -4.130856056073769

# %%
import numpy as np

def find_local_max_windowed(freqs, powers, window_half_dex=0.05, window_protect_dex=0.1):
    """
    Identify local max frequency in windowed summed power spectrum, split separately
    for positive and negative frequencies.
    """
    # Separate positive and negative frequencies
    pos_mask = freqs > 0
    neg_mask = freqs < 0

    freqs_pos = freqs[pos_mask]
    powers_pos = powers[pos_mask]
    freqs_neg = freqs[neg_mask]
    powers_neg = powers[neg_mask]

    # Sort and log-transform positive frequencies
    logf_pos = np.log10(freqs_pos)
    sort_idx_pos = np.argsort(logf_pos)
    logf_pos = logf_pos[sort_idx_pos]
    powers_pos = powers_pos[sort_idx_pos]
    freqs_pos = freqs_pos[sort_idx_pos]

    # Sort and log-transform negative frequencies
    logf_neg = np.log10(-freqs_neg)
    sort_idx_neg = np.argsort(logf_neg)
    logf_neg = logf_neg[sort_idx_neg]
    powers_neg = powers_neg[sort_idx_neg]
    freqs_neg = freqs_neg[sort_idx_neg]

    # Cumulative sums
    cumsum_pos = np.cumsum(powers_pos)
    cumsum_neg = np.cumsum(powers_neg)

    # Initialize local power arrays
    local_power_pos = np.zeros_like(powers_pos)
    local_power_neg = np.zeros_like(powers_neg)

    # Compute windowed sums for positive
    for i in range(len(logf_pos)):
        center = logf_pos[i]
        min_logf = center - window_half_dex
        max_logf = center + window_half_dex

        left = np.searchsorted(logf_pos, min_logf, side='left')
        right = np.searchsorted(logf_pos, max_logf, side='right') - 1

        if left == 0:
            local_power_pos[i] = cumsum_pos[right]
        else:
            local_power_pos[i] = cumsum_pos[right] - cumsum_pos[left - 1]

    # Compute windowed sums for negative
    for i in range(len(logf_neg)):
        center = logf_neg[i]
        min_logf = center - window_half_dex
        max_logf = center + window_half_dex

        left = np.searchsorted(logf_neg, min_logf, side='left')
        right = np.searchsorted(logf_neg, max_logf, side='right') - 1

        if left == 0:
            local_power_neg[i] = cumsum_neg[right]
        else:
            local_power_neg[i] = cumsum_neg[right] - cumsum_neg[left - 1]

    # Recombine into full array
    local_power_all = np.zeros_like(freqs)
    unsort_idx_pos = np.argsort(sort_idx_pos)
    unsort_idx_neg = np.argsort(sort_idx_neg)
    local_power_all[pos_mask] = local_power_pos[unsort_idx_pos]
    local_power_all[neg_mask] = local_power_neg[unsort_idx_neg]

    # Find global maximum
    max_idx = np.argmax(local_power_all)
    max_freq = freqs[max_idx]
    #dominant_freq = freqs[max_idx]

    #if dominant_freq < 0:
    #    in_window = np.where((np.log10(-freqs) >= min_logf) & (np.log10(-freqs) <= max_logf))[0]
    #else:
    #    in_window = np.where((np.log10(freqs) >= min_logf) & (np.log10(freqs) <= max_logf))[0]
        
    #plt.plot(-1/freqs,local_power_all)
    #plt.vlines(abs(1/dominant_freq),ymin=1e-3,ymax=1e7)
    #plt.vlines(abs(1/max_freq),ymin=1e-3,ymax=1e7)
    #plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=1e-3,ymax=1e7,colors='r')
    #plt.yscale('log')
    #plt.xscale('log')
    #plt.xlim(abs(0.5/freqs[np.min(in_window)]),abs(2/freqs[np.max(in_window)]))
    #plt.ylim(5e6,8e6)
    #plt.show()

    min_logf = np.log10(abs(max_freq)) - window_half_dex
    max_logf = np.log10(abs(max_freq)) + window_half_dex

    ind_low = np.argmin(abs(freqs-10**min_logf))
    ind_high = np.argmin(abs(freqs-10**max_logf))

    if max_freq < 0:
        ind_high = np.argmin(abs(freqs+10**min_logf))
        ind_low = np.argmin(abs(freqs+10**max_logf))

    #max_idx = np.argmax(powers[ind_low:ind_high])+ind_low
    print(max_freq,max_freq*2*np.pi*206265)
    dominant_freq = np.sum(freqs[ind_low:ind_high]*(powers[ind_low:ind_high]))/np.sum((powers[ind_low:ind_high]))
    print(dominant_freq,dominant_freq*2*np.pi*206265)
    max_idx = np.argmin(np.abs(freqs-dominant_freq))
    
    #min_logf = np.log10(abs(dominant_freq)) - window_protect_dex
    #max_logf = np.log10(abs(dominant_freq)) + window_protect_dex

    if dominant_freq < 0:
        in_window = np.where((np.log10(-freqs) >= min_logf) & (np.log10(-freqs) <= max_logf))[0]
    else:
        in_window = np.where((np.log10(freqs) >= min_logf) & (np.log10(freqs) <= max_logf))[0]
                
    #protect_bins = round((np.max(in_window)-np.min(in_window))/2)
    '''
    protect_bins = 10
    plt.plot(-1/freqs,local_power_all)
    plt.vlines(abs(1/dominant_freq),ymin=1e-3,ymax=1e7)
    plt.vlines(abs(1/max_freq),ymin=1e-3,ymax=1e7)
    #plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=1e-3,ymax=1e7,colors='r')
    plt.yscale('log')
    plt.xscale('log')
    plt.xlim(abs(0.5/freqs[np.min(in_window)]),abs(2/freqs[np.max(in_window)]))
    #plt.xlim(2e4,2e5)
    #plt.ylim(5e6,8e6)
    plt.show()
    plt.plot(-1/freqs,powers)
    plt.vlines(abs(1/dominant_freq),ymin=1e-3,ymax=1e7)
    plt.vlines(abs(1/max_freq),ymin=1e-3,ymax=1e7)
    #plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=1e-3,ymax=1e7,colors='r')
    plt.xlim(abs(0.5/freqs[np.min(in_window)]),abs(2/freqs[np.max(in_window)]))
    plt.yscale('log')
    plt.xscale('log')
    #plt.xlim(2e4,2e5)
    plt.show()
    '''
    plt.plot(1/freqs,local_power_all)
    #plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='r')
    plt.yscale('log')
    plt.xscale('log')
    plt.xlim(0.7*abs(1/freqs[np.min(in_window)]),1.8*abs(1/freqs[np.max(in_window)]))
    #plt.xlim(0.5*abs(1/freqs[np.min(in_window)]),1.1*abs(2/freqs[np.max(in_window)]))
    #plt.ylim(1e3,6e7)
    plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='r')
    plt.vlines(abs(1/dominant_freq),ymin=plt.ylim()[0],ymax=plt.ylim()[1])
    plt.vlines(abs(1/max_freq),ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='g')
    plt.vlines(abs(1/2.022e-5),ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='k')
    plt.show()
    #'''
    plt.plot(1/freqs,powers)
    plt.yscale('log')
    plt.xscale('log')
    plt.xlim(0.7*abs(1/freqs[np.min(in_window)]),1.8*abs(1/freqs[np.max(in_window)]))
    #plt.xlim(0.5*abs(1/freqs[np.min(in_window)]),1.1*abs(2/freqs[np.max(in_window)]))
    #plt.ylim(2e3,6e7)
    plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='r')
    plt.vlines(abs(1/dominant_freq),ymin=plt.ylim()[0],ymax=plt.ylim()[1])
    plt.vlines(abs(1/max_freq),ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='g')
    plt.show()
    #'''
    protect_bins = 10

    return max_idx, dominant_freq, local_power_all, protect_bins



pq_zp = pq.copy()
#pq_zp = hk_new.copy()
N = len(pq_zp)
goal = 2**16
#goal = len(pq_zp)
#pq_zp = np.append(pq_zp, np.zeros(goal-N))
#print(pq_zp)

freqs = np.fft.fftfreq(len(pq_zp),1000)

window_dex = 0.25
n_bins = len(freqs)

local_power = np.zeros(n_bins)
window_half_dex = window_dex / 2

Ypq_zp = np.fft.fft(pq_zp)
powers = np.abs(Ypq_zp)**2

og_tol = 1/10001/1000
new_tol = 1/len(pq_zp)/1000
tol_bins = round(og_tol/new_tol)
window_half_dex=0.02/5
ind_low = np.argmin(abs(freqs - (10**(np.log10(abs(s_arr[0])) - window_half_dex))))
ind = np.argmin(abs(freqs - s_arr[0]))

dist = int(abs(ind-ind_low))
#dist = round(tol_bins*2)
for i in s_arr[:8]:
    ind = np.argmin(abs(freqs-i))
    powers[ind-dist:ind+dist+1] = powers[ind-dist:ind+dist+1]/50

print(find_local_max_windowed(freqs, powers, window_half_dex=0.02, window_protect_dex=0.15))
print(np.array(g_arr)*2*np.pi*206265)
print(np.array(s_arr)*2*np.pi*206265)
print(s_arr)
# Out:
# 5.139486051394861e-05 66.60780179343008
# 5.143887341782704e-05 66.6648425704372
# (514, 5.143887341782704e-05, array([0.        , 1.55036314, 1.28215827, ..., 2.1016143 , 2.03267094,
#        1.90051208]), 10)
# [ -4.27629085 -28.24943655  -3.11002971  -0.64792286  -7.12715142
#  -17.6235017  -17.10516342 -52.22258225 -53.38884339 -76.19572794
#  -27.08317541 -29.41569769 -81.50869537 -27.60151369  19.69685484]
# [ 26.30566798   2.98044514   0.64792286  18.5305937   17.75308627
#    6.22005942 -52.22258225 -53.38884339 -76.19572794 -27.08317541
#  -29.41569769 -81.50869537 -27.60151369  19.69685484]
# [2.029756425170822e-05, 2.2997240285186655e-06, 4.999400061997099e-07, 1.4298284177311702e-05, 1.369835616987205e-05, 4.799424059517215e-06, -4.029516449969662e-05, -4.1195056510856095e-05, -5.8792944729085884e-05, -2.0897492259147876e-05, -2.2697276281466827e-05, -6.28924527799235e-05, -2.129744426410764e-05, 1.519817618847118e-05]

# %%
import numpy as np

def find_local_max_windowed(freqs, powers, window_half_dex=0.05, window_protect_dex=0.1):
    """
    Identify local max frequency in windowed summed power spectrum, split separately
    for positive and negative frequencies.
    """
    # Separate positive and negative frequencies
    pos_mask = freqs > 0
    neg_mask = freqs < 0

    freqs_pos = freqs[pos_mask]
    powers_pos = powers[pos_mask]
    freqs_neg = freqs[neg_mask]
    powers_neg = powers[neg_mask]

    # Sort and log-transform positive frequencies
    logf_pos = np.log10(freqs_pos)
    sort_idx_pos = np.argsort(logf_pos)
    logf_pos = logf_pos[sort_idx_pos]
    powers_pos = powers_pos[sort_idx_pos]
    freqs_pos = freqs_pos[sort_idx_pos]

    # Sort and log-transform negative frequencies
    logf_neg = np.log10(-freqs_neg)
    sort_idx_neg = np.argsort(logf_neg)
    logf_neg = logf_neg[sort_idx_neg]
    powers_neg = powers_neg[sort_idx_neg]
    freqs_neg = freqs_neg[sort_idx_neg]

    # Cumulative sums
    cumsum_pos = np.cumsum(powers_pos)
    cumsum_neg = np.cumsum(powers_neg)

    # Initialize local power arrays
    local_power_pos = np.zeros_like(powers_pos)
    local_power_neg = np.zeros_like(powers_neg)

    # Compute windowed sums for positive
    for i in range(len(logf_pos)):
        center = logf_pos[i]
        min_logf = center - window_half_dex
        max_logf = center + window_half_dex

        left = np.searchsorted(logf_pos, min_logf, side='left')
        right = np.searchsorted(logf_pos, max_logf, side='right') - 1

        if left == 0:
            local_power_pos[i] = cumsum_pos[right]
        else:
            local_power_pos[i] = cumsum_pos[right] - cumsum_pos[left - 1]

    # Compute windowed sums for negative
    for i in range(len(logf_neg)):
        center = logf_neg[i]
        min_logf = center - window_half_dex
        max_logf = center + window_half_dex

        left = np.searchsorted(logf_neg, min_logf, side='left')
        right = np.searchsorted(logf_neg, max_logf, side='right') - 1

        if left == 0:
            local_power_neg[i] = cumsum_neg[right]
        else:
            local_power_neg[i] = cumsum_neg[right] - cumsum_neg[left - 1]

    # Recombine into full array
    local_power_all = np.zeros_like(freqs)
    unsort_idx_pos = np.argsort(sort_idx_pos)
    unsort_idx_neg = np.argsort(sort_idx_neg)
    local_power_all[pos_mask] = local_power_pos[unsort_idx_pos]
    local_power_all[neg_mask] = local_power_neg[unsort_idx_neg]

    # Find global maximum
    max_idx = np.argmax(local_power_all)
    max_freq = freqs[max_idx]
    #dominant_freq = freqs[max_idx]

    #if dominant_freq < 0:
    #    in_window = np.where((np.log10(-freqs) >= min_logf) & (np.log10(-freqs) <= max_logf))[0]
    #else:
    #    in_window = np.where((np.log10(freqs) >= min_logf) & (np.log10(freqs) <= max_logf))[0]
        
    #plt.plot(-1/freqs,local_power_all)
    #plt.vlines(abs(1/dominant_freq),ymin=1e-3,ymax=1e7)
    #plt.vlines(abs(1/max_freq),ymin=1e-3,ymax=1e7)
    #plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=1e-3,ymax=1e7,colors='r')
    #plt.yscale('log')
    #plt.xscale('log')
    #plt.xlim(abs(0.5/freqs[np.min(in_window)]),abs(2/freqs[np.max(in_window)]))
    #plt.ylim(5e6,8e6)
    #plt.show()

    min_logf = np.log10(abs(max_freq)) - window_half_dex
    max_logf = np.log10(abs(max_freq)) + window_half_dex

    
    ind_low = np.argmin(abs(freqs-10**min_logf))
    ind_high = np.argmin(abs(freqs-10**max_logf))

    if max_freq < 0:
        ind_high = np.argmin(abs(freqs+10**min_logf))
        ind_low = np.argmin(abs(freqs+10**max_logf))

    #max_idx = np.argmax(powers[ind_low:ind_high])+ind_low
    #print(max_freq,max_freq*2*np.pi*206265)

    if ind_high - ind_low <= 1:
        ind_low = max_idx - 1
        ind_high = max_idx + 1
    
    dominant_freq = np.sum(freqs[ind_low:ind_high+1]*(powers[ind_low:ind_high+1])**2)/np.sum((powers[ind_low:ind_high+1]**2))
    #print(dominant_freq,dominant_freq*2*np.pi*206265)
    max_idx = np.argmin(np.abs(freqs-dominant_freq))
    dominant_freq = freqs[max_idx]
    
    #min_logf = np.log10(abs(dominant_freq)) - window_protect_dex
    #max_logf = np.log10(abs(dominant_freq)) + window_protect_dex

    if dominant_freq < 0:
        in_window = np.where((np.log10(-freqs) >= min_logf) & (np.log10(-freqs) <= max_logf))[0]
    else:
        in_window = np.where((np.log10(freqs) >= min_logf) & (np.log10(freqs) <= max_logf))[0]
 
    protect_bins = 10
    '''
    print(ind_high-ind_low)
    print(1/abs(dominant_freq))
    fig,ax = plt.subplots(1,2,figsize=(9,3))
    ax[0].scatter(-1/freqs,local_power_all,s=5)
    ax[0].vlines(abs(1/dominant_freq),ymin=1e-3,ymax=1e7,colors='r')
    ax[0].vlines([abs(1/freqs[ind_high]),abs(1/freqs[ind_low])],ymin=1e-3,ymax=1e7,colors='r')
    ax[0].set_yscale('log')
    ax[0].set_xscale('log')
    #ax[0].set_xlim(2e4,2e5)
    #plt.set_ylim(5e6,8e6)
    #plt.show()
    ax[1].scatter(-1/freqs,powers,s=5)
    ax[1].vlines(abs(1/dominant_freq),ymin=1e-3,ymax=1e7,colors='r')
    ax[1].vlines([abs(1/freqs[ind_high]),abs(1/freqs[ind_low])],ymin=1e-3,ymax=1e7,colors='r')
    #ax[1].vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=1e-3,ymax=1e7,colors='r')
    ax[1].set_yscale('log')
    ax[1].set_xscale('log')
    ax[0].set_title('Positive')
    #ax[1].set_xlim(2e4,2e5)
    plt.show()

    fig,ax = plt.subplots(1,2,figsize=(9,3))
    ax[0].scatter(1/freqs,local_power_all,s=5)
    ax[0].vlines(abs(1/dominant_freq),ymin=1e-3,ymax=1e7,colors='r')
    ax[0].vlines([abs(1/freqs[ind_high]),abs(1/freqs[ind_low])],ymin=1e-3,ymax=1e7,colors='r')
    #ax[0].vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=1e-3,ymax=1e7,colors='r')
    ax[0].set_yscale('log')
    ax[0].set_xscale('log')
    #ax[0].set_xlim(2e4,2e5)
    #plt.set_ylim(5e6,8e6)
    #plt.show()
    ax[1].scatter(1/freqs,powers,s=5)
    ax[1].vlines(abs(1/dominant_freq),ymin=1e-3,ymax=1e7,colors='r')
    ax[1].vlines([abs(1/freqs[ind_high]),abs(1/freqs[ind_low])],ymin=1e-3,ymax=1e7,colors='r')
    #ax[1].vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=1e-3,ymax=1e7,colors='r')
    ax[1].set_yscale('log')
    ax[1].set_xscale('log')
    ax[0].set_title('Negative')
    #ax[1].set_xlim(2e4,2e5)
    plt.show()
    #'''

    plt.scatter(-1/freqs,local_power_all,s=5)
    #plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='r')
    plt.yscale('log')
    plt.xscale('log')
    plt.xlim(0.75*abs(1/freqs[np.min(in_window)]),1.95*abs(1/freqs[np.max(in_window)]))
    #plt.xlim(0.5*abs(1/freqs[np.min(in_window)]),1.1*abs(2/freqs[np.max(in_window)]))
    #plt.ylim(1e3,6e7)
    plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='r')
    plt.vlines(abs(1/dominant_freq),ymin=plt.ylim()[0],ymax=plt.ylim()[1])
    plt.vlines(abs(1/max_freq),ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='g')
    plt.vlines(abs(1/2.022e-5),ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='k')
    plt.show()
    
    #'''
    plt.scatter(-1/freqs,powers,s=5)
    plt.yscale('log')
    plt.xscale('log')
    plt.xlim(0.75*abs(1/freqs[np.min(in_window)]),1.9*abs(1/freqs[np.max(in_window)]))
    #plt.xlim(0.5*abs(1/freqs[np.min(in_window)]),1.1*abs(2/freqs[np.max(in_window)]))
    #plt.ylim(2e3,6e7)
    plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='r')
    plt.vlines(abs(1/dominant_freq),ymin=plt.ylim()[0],ymax=plt.ylim()[1])
    plt.vlines(abs(1/max_freq),ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='g')
    plt.show()

    plt.scatter(1/freqs,local_power_all,s=5)
    #plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='r')
    plt.yscale('log')
    plt.xscale('log')
    plt.xlim(0.75*abs(1/freqs[np.min(in_window)]),1.95*abs(1/freqs[np.max(in_window)]))
    #plt.xlim(0.5*abs(1/freqs[np.min(in_window)]),1.1*abs(2/freqs[np.max(in_window)]))
    #plt.ylim(1e3,6e7)
    plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='r')
    plt.vlines(abs(1/dominant_freq),ymin=plt.ylim()[0],ymax=plt.ylim()[1])
    plt.vlines(abs(1/max_freq),ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='g')
    plt.vlines(abs(1/2.022e-5),ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='k')
    plt.show()
    
    #'''
    plt.scatter(1/freqs,powers,s=5)
    plt.yscale('log')
    plt.xscale('log')
    plt.xlim(0.75*abs(1/freqs[np.min(in_window)]),1.9*abs(1/freqs[np.max(in_window)]))
    #plt.xlim(0.5*abs(1/freqs[np.min(in_window)]),1.1*abs(2/freqs[np.max(in_window)]))
    #plt.ylim(2e3,6e7)
    plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='r')
    plt.vlines(abs(1/dominant_freq),ymin=plt.ylim()[0],ymax=plt.ylim()[1])
    plt.vlines(abs(1/max_freq),ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='g')
    plt.show()

    plt.scatter(-1/freqs,local_power_all,s=5)
    #plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='r')
    plt.yscale('log')
    plt.xscale('log')
    #plt.xlim(0.75*abs(1/freqs[np.min(in_window)]),1.95*abs(1/freqs[np.max(in_window)]))
    #plt.xlim(0.5*abs(1/freqs[np.min(in_window)]),1.1*abs(2/freqs[np.max(in_window)]))
    #plt.ylim(1e3,6e7)
    plt.xlim(abs(s[0].t*2),abs(s[-1].t))
    plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='r')
    plt.vlines(abs(1/dominant_freq),ymin=plt.ylim()[0],ymax=plt.ylim()[1])
    plt.vlines(abs(1/np.array(g_arr)),ymin=plt.ylim()[0],ymax=plt.ylim()[1])
    plt.vlines(abs(1/max_freq),ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='g')
    plt.vlines(abs(1/2.022e-5),ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='k')
    plt.show()

    plt.scatter(1/freqs,local_power_all,s=5)
    #plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='r')
    plt.yscale('log')
    plt.xscale('log')
    #plt.xlim(0.75*abs(1/freqs[np.min(in_window)]),1.95*abs(1/freqs[np.max(in_window)]))
    #plt.xlim(0.5*abs(1/freqs[np.min(in_window)]),1.1*abs(2/freqs[np.max(in_window)]))
    #plt.ylim(1e3,6e7)
    
    plt.xlim(abs(s[0].t*2),abs(s[-1].t))
    plt.vlines([abs(1/freqs[np.max(in_window)]),abs(1/freqs[np.min(in_window)])],ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='r')
    plt.vlines(abs(1/dominant_freq),ymin=plt.ylim()[0],ymax=plt.ylim()[1])
    plt.vlines(abs(1/max_freq),ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='g')
    plt.vlines(abs(1/2.022e-5),ymin=plt.ylim()[0],ymax=plt.ylim()[1],colors='k')
    plt.show()
    #'''
    protect_bins = 10

    print('Period', 1/dominant_freq)
    return max_idx, dominant_freq, local_power_all, protect_bins



pq_zp = hk.copy()
#pq_zp = hk_new.copy()
N = len(pq_zp)
goal = 2**16
#goal = len(pq_zp)
#pq_zp = np.append(pq_zp, np.zeros(goal-N))
#print(pq_zp)

freqs = np.fft.fftfreq(len(pq_zp),dt)

window_dex = 0.25
n_bins = len(freqs)

local_power = np.zeros(n_bins)
window_half_dex = window_dex / 2

Ypq_zp = np.fft.fft(pq_zp)
powers = np.abs(Ypq_zp)**2

og_tol = 1/10001/dt
new_tol = 1/len(pq_zp)/dt
tol_bins = round(og_tol/new_tol)
print(tol_bins)
window_half_dex=0.02/5
ind_low = np.argmin(abs(freqs - (10**(np.log10(abs(g_arr[0])) - window_half_dex))))
ind = np.argmin(abs(freqs - g_arr[0]))

dist = int(abs(ind-ind_low))
dist = round(tol_bins*2)

small_planets_flag = 0
if small_planets_flag:
    num_p = 8
else:
    num_p = 5

j=0
for i in g_arr[:num_p]:
    ind = np.argmin(abs(freqs-i))
    if j==0 or j==1:
        mult = 100
    else:
        mult = 20
    if small_planets_flag == False and j == 3:
        mult = 100
        
    powers[ind-dist:ind+dist+1] = powers[ind-dist:ind+dist+1]/mult
    j+=1

short_period_g = np.min(1/abs(np.array(g_arr)))
short_period_s = np.min(1/abs(np.array(s_arr)))
short_period = min(short_period_g,short_period_s)
short_period = min(short_period,abs(1/(2*g_arr[1]-2*s_arr[0])))

short_ind = np.where(1/abs(freqs) < short_period/4)[0]
print(short_period)
powers[short_ind] = powers[short_ind]/5

print(find_local_max_windowed(freqs, powers, window_half_dex=0.05, window_protect_dex=0.15))
print(np.array(g_arr)*2*np.pi*206265)
print(np.array(s_arr)*2*np.pi*206265)
print(s_arr)
# Out:
# 1
# 11872.507169984907
# Period -11112666.711105872
# (9992, -8.998740140389627e-08, array([   0.        , 1863.42294198, 1485.02829919, ..., 4803.82320652,
#        3544.62010475, 2729.92837771]), 10)
# [  -4.25028894  -28.23591339   -3.08405112   -0.67382629  -52.22153784
#   -53.38777565  -76.20716229  -27.06967557  -29.4021512   -81.55889805
#   -27.60096169   19.73533551 -109.15985974]
# [  26.34401648    2.99334373    0.68678449  -52.22153784  -53.38777565
#   -76.20716229  -27.06967557  -29.4021512   -81.55889805  -27.60096169
#    19.73533551 -109.15985974]
# [2.032715411712457e-05, 2.3096766360333376e-06, 5.299258082673892e-07, -4.029435862863355e-05, -4.1194232642672514e-05, -5.8801767517368225e-05, -2.0887075725859924e-05, -2.2686823753937847e-05, -6.293118938179146e-05, -2.1297018332255452e-05, 1.5227868037570447e-05, -8.422820771404691e-05]

# %%
print(0.000357*2*np.pi*206265)
print(1/(401/2/np.pi/206265))
print(1/np.array(g_arr[:8]))
print(1/np.array(s_arr[:8]))

print(2*np.pi*206265*np.array(g_arr[:8]))
print(2*np.pi*206265*np.array(s_arr[:8]))
print(1/g[0])
# Out:
# 462.6724346065869
# 3231.923235375056
# [ -304920.73292669   -45899.03643871  -420226.89243678 -1923346.16153755
#    -24817.36982629   -24275.24281552   -17006.29151504   -47876.49612252]
# [  49195.27811114  432961.04069244 1887056.61131987  -24817.36982629
#   -24275.24281552  -17006.29151504  -47876.49612252  -44078.44883206]
# [ -4.25028894 -28.23591339  -3.08405112  -0.67382629 -52.22153784
#  -53.38777565 -76.20716229 -27.06967557]
# [ 26.34401648   2.99334373   0.68678449 -52.22153784 -53.38777565
#  -76.20716229 -27.06967557 -29.4021512 ]
# -10923103.573328186

# %%
print(1/(2*g_arr[1]-2*s_arr[0]))
print(1/(4*s_arr[0]))
print(1/(4*g_arr[1]))
# Out:
# -11877.909762462377
# 12316.748793095225
# -11469.266077973993

# %%
print(min_logf,max_logf)
plt.scatter(-1/freqs,powers,s=5)
plt.vlines(-1/dominant_freq,ymin=1e-3,ymax=1e5)
plt.vlines(1/np.array([10**min_logf,10**max_logf]),ymin=1e-3,ymax=1e3,colors='r')
plt.xscale('log')
plt.yscale('log')
plt.xlim(3e4,6e4)
plt.show()
plt.scatter(1/freqs,np.abs(Ypq_zp)**2,s=5)
plt.vlines(-1/dominant_freq,ymin=1e-3,ymax=1e3)
plt.xscale('log')
plt.yscale('log')
plt.show()

plt.plot(local_power)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(min_logf,max_logf)
#       2 plt.scatter(-1/freqs,powers,s=5)
#       3 plt.vlines(-1/dominant_freq,ymin=1e-3,ymax=1e5)
#
# NameError: name 'min_logf' is not defined

# %%
pq_zp = pq.copy()
#pq_zp = hk_new.copy()
N = len(pq_zp)
goal = 2**14
pq_zp = np.append(pq_zp, np.zeros(goal-N))
print(pq_zp)

freqs = np.fft.fftfreq(len(pq_zp),1000)

window_dex = 0.1  
n_bins = len(freqs)

local_power = np.zeros(n_bins)
window_half_dex = window_dex / 2

Ypq_zp = np.fft.fft(pq_zp)
powers = np.abs(Ypq_zp)**2
n_bins = len(Ypq_zp)

for i in range(n_bins):
    if freqs[i] < 0:
        center_logf = np.log10(-freqs[i])
    else:
        center_logf = np.log10(freqs[i])
    # Define window boundaries
    min_logf = center_logf - window_half_dex
    max_logf = center_logf + window_half_dex
    # Find indices inside window
    if freqs[i] < 0:
        in_window = (np.log10(-freqs) >= min_logf) & (np.log10(-freqs) <= max_logf)
    else:
        in_window = (np.log10(freqs) >= min_logf) & (np.log10(freqs) <= max_logf)        
    # Sum power inside window
    local_power[i] = np.sum(powers[in_window])

# Find index of maximum integrated power
max_idx = np.argmax(local_power)
dominant_freq = freqs[max_idx]
dominant_power_sum = local_power[max_idx]

print(f"Dominant region center frequency: {dominant_freq:.6e} [1/yr]")
print(f"Approximate period: {1/dominant_freq:.1f} yr")
print(f"Total integrated power in this region: {dominant_power_sum:.2f}")

min_logf = np.log10(-dominant_freq) - window_half_dex
max_logf = np.log10(-dominant_freq) + window_half_dex


print(min_logf,max_logf)
plt.scatter(-1/freqs,np.abs(Ypq_zp)**2,s=5)
plt.vlines(-1/dominant_freq,ymin=1e-3,ymax=1e5)
plt.vlines(1/np.array([10**min_logf,10**max_logf]),ymin=1e-3,ymax=1e3,colors='r')
plt.xscale('log')
plt.yscale('log')
plt.xlim(2e3,8e3)
plt.show()
plt.scatter(1/freqs,np.abs(Ypq_zp)**2,s=5)
plt.vlines(-1/dominant_freq,ymin=1e-3,ymax=1e3)
plt.xscale('log')
plt.yscale('log')
plt.show()

plt.plot(local_power)
plt.yscale('log')
plt.show()
plt.plot(powers)
plt.yscale('log')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 pq_zp = pq.copy()
#       2 #pq_zp = hk_new.copy()
#       3 N = len(pq_zp)
#
# NameError: name 'pq' is not defined

# %%
print(1/s_freq)
print(1/(g[0]+2*s_freq[0]))
print(1/np.array(s_arr))

print('g period',1/g[0])
print(1/np.array(g_arr))
# Out:
# [  19547.64288931    9773.82144465    6515.8809631    -9378.49883382
#    -6169.15773505   -6337.78081419   -4689.24941691 -231870.80755956]
# 21347.306826690165
# [  49223.23636559  434743.52785876 1942224.22537173   69858.98455927
#    73161.50159155  209055.04025189   55508.05989308   50503.17600237
#   560119.55113183   25764.03300731  -98446.47273117  -11872.82645837]
# g period -18027.824666557306
# [ -303106.33184721   -45877.10951951  -417092.94101183 -1991051.85409966
#    -73723.5758425    -75613.82961368  -180967.88228156    54059.34153351
#  -1109108.44980822  -357535.48681383   -51546.88165559   -46959.12499588
#   -527620.9351007    -24816.63403046   -24273.50703435   -17008.61238384
#     58815.68114175   -22938.55475976   -91754.21903903]

# %%
pq_zp = pq.copy()
goal = 2**15
pq_zp = np.append(pq_zp,np.zeros(goal-len(pq_zp)))
freqs = np.fft.fftfreq(len(pq_zp),1000)

power = np.abs(np.fft.fft(pq_zp))**2

power[abs(1/freqs) > 1e7] = 0

sort_idx = np.argsort(freqs)
sorted_powers = power[sort_idx]
sorted_log_freqs = freqs[sort_idx]
local_power = np.zeros(len(power))

cumsum_power = np.cumsum(sorted_powers)

print(len(log_freqs),len(sorted_log_freqs))
window_dex = 0.001
window_half_dex = window_dex/2

for i in range(len(sorted_log_freqs)):
    center = sorted_log_freqs[i]
    
    min_edge = 10**(np.log10(abs(center)) - window_half_dex)
    max_edge = 10**(np.log10(abs(center)) + window_half_dex)
    if center < 0:
        min_edge = -max_edge
        max_edge = -min_edge

    # Find indices of window edges
    left_idx = np.searchsorted(sorted_log_freqs, min_edge, side="left")
    right_idx = np.searchsorted(sorted_log_freqs, max_edge, side="right")

    # Sum power in window using cumulative sum
    window_sum = cumsum_power[right_idx - 1]
    if left_idx > 0:
        window_sum -= cumsum_power[left_idx - 1]         
                    
    local_power[i] = window_sum

sort_idx_max = np.argmax(local_power)
s_idx = sort_idx[sort_idx_max]
s = freqs[s_idx]

print(s, 1/s)

plt.plot(1/freqs,power)
plt.xscale('log')
plt.yscale('log')
plt.vlines(1/s,ymin=1e-3,ymax=1e4,colors='r')
plt.vlines(1/np.array([10**(np.log10(abs(s)-window_half_dex)),10**(np.log10(abs(s))+window_half_dex)]),ymin=1e-3,ymax=1e4,colors='g')
plt.show()
plt.plot(1/freqs,power)
plt.xscale('log')
plt.yscale('log')
plt.vlines(1/s,ymin=1e-3,ymax=1e4,colors='r')
plt.vlines(1/np.array([10**(np.log10(abs(s))-window_half_dex),10**(np.log10(abs(s))+window_half_dex)]),ymin=1e-3,ymax=1e4,colors='g')
plt.xlim(1/s-3e3,1/s+3e4)
plt.show()

plt.plot(local_power)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 17
#      13 local_power = np.zeros(len(power))
#      15 cumsum_power = np.cumsum(sorted_powers)
# ---> 17 print(len(log_freqs),len(sorted_log_freqs))
#      18 window_dex = 0.001
#      19 window_half_dex = window_dex/2
#
# NameError: name 'log_freqs' is not defined

# %%
print(1/np.array(s_arr))
print(1/np.array(g_arr))
print(1/s_freq[0])
print(1/(s_arr[0]-s_arr[1]))
print(1/(g[0]-s_freq[0]))

print(1/g[0])
print(g[0])
print(1/(g[0]*2))

# %%
pq_zp = pq_new.copy()
N = len(pq_zp)
goal = 2**17
#pq_zp = np.append(pq_zp, np.zeros(goal-N))
#print(pq_zp)

freq_zp = np.fft.fftfreq(len(pq_zp),10000)

Ypq_zp = np.fft.fft(pq_zp)

fig,ax = plt.subplots(1,2,figsize=(10,3))

ax[0].scatter(1/(freq_zp),np.abs(Ypq_zp)**2,s=5)
#ax[0].vlines(1/s_freq,ymin=1e-3,ymax=1e4)
ax[0].set_yscale('log')
ax[0].set_xscale('log')
#plt.show()
freq = np.fft.fftfreq(len(pq),dt)
ax[1].scatter(1/(freq),np.abs(np.fft.fft(pq))**2,s=5)
#ax[1].vlines(49266,ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1])
#ax[0].vlines(49266,ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].vlines(-1/np.array(s_arr),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(1/np.array(s_arr),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(1/s_ex,ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].set_xlim(1e6,3.5e6)
#ax[1].set_xlim(1e6,3.5e6)
ax[1].set_yscale('log')
ax[1].set_xscale('log')
plt.show()

hk_zp = hk.copy()
hk_zp = np.append(hk_zp, np.zeros(goal-N))
print(len(hk_zp))

freq_zp = np.fft.fftfreq(len(hk_zp),10000)
freq = np.fft.fftfreq(len(hk),1000)

Yhk_zp = np.fft.fft(hk_zp)

fig,ax = plt.subplots(1,2,figsize=(10,3))
ax[0].scatter(1/np.flip(freq),np.abs(np.fft.fft(hk_new))**2,s=5)
#ax[0].vlines(1/s_freq,ymin=1e-3,ymax=1e4)
ax[0].set_yscale('log')
#ax[0].set_xscale('log')
#plt.show()
freq = np.fft.fftfreq(len(hk_sig),dt)
ax[1].scatter(1/np.flip(freq),np.abs(hk_sig)**2,s=5)
#ax[1].vlines(49266,ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1])
#ax[0].vlines(49266,ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].vlines(-1/np.array(s_arr),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(1/np.array(s_arr),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(1/s_ex,ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].set_xlim(5e3,1e8)
#ax[0].set_xlim(1e6,6e6)
#ax[1].set_xlim(1e6,6e6)
ax[0].set_xlim(abs(1/g[0])-9e3,1/abs(g[0])+9e3)
ax[1].set_xlim(1/abs(g[0])-9e3,1/abs(g[0])+9e3)
ax[1].set_yscale('log')
#ax[1].set_xscale('log')
plt.show()

freq = np.fft.fftfreq(len(hk),1000)
fig,ax = plt.subplots(1,2,figsize=(10,3))
ax[0].scatter(1/np.flip(freq),np.abs(np.fft.fft(hk))**2,s=5)
#ax[0].vlines(1/s_freq,ymin=1e-3,ymax=1e4)
ax[0].set_yscale('log')
ax[0].set_xscale('log')
#plt.show()
freq = np.fft.fftfreq(len(hk_sig),dt)
ax[1].scatter(1/np.flip(freq),np.abs(hk_sig)**2,s=5)
#ax[1].vlines(49266,ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1])
#ax[0].vlines(49266,ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].vlines(-1/np.array(s_arr),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(1/np.array(s_arr),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(1/s_ex,ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].set_xlim(5e3,1e8)
#ax[0].set_xlim(1e6,6e6)
#ax[1].set_xlim(1e6,6e6)
#ax[0].set_xlim(abs(1/g[0])-9e3,1/abs(g[0])+9e3)
#ax[1].set_xlim(1/abs(g[0])-9e3,1/abs(g[0])+9e3)
ax[1].set_yscale('log')
ax[1].set_xscale('log')
plt.show()
print(1/g)

# %%
hk_zp = hk.copy()
hk_zp = hk_new.copy()
N = len(hk_zp)
goal = 2**17
#pq_zp = np.append(pq_zp, np.zeros(goal-N))
#print(pq_zp)

freq_zp = np.fft.fftfreq(len(hk_zp),10000)

Yhk_zp = np.fft.fft(hk_zp)

fig,ax = plt.subplots(1,2,figsize=(10,3))

ax[0].scatter(1/(freq_zp),np.abs(Yhk_zp)**2,s=5)
#ax[0].vlines(1/s_freq,ymin=1e-3,ymax=1e4)
ax[0].set_yscale('log')
#ax[0].set_xscale('log')
#plt.show()
freq = np.fft.fftfreq(len(hk),dt)
ax[1].scatter(1/(freq),np.abs(np.fft.fft(hk))**2,s=5)
#ax[1].vlines(49266,ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1])
#ax[0].vlines(49266,ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].vlines(-1/np.array(s_arr),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(1/np.array(s_arr),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(1/s_ex,ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
ax[0].set_xlim(1e6,3.5e6)
ax[1].set_xlim(1e6,3.5e6)
ax[1].set_yscale('log')
#ax[1].set_xscale('log')
plt.show()

hk_zp = hk.copy()
hk_zp = np.append(hk_zp, np.zeros(goal-N))
print(len(hk_zp))

freq_zp = np.fft.fftfreq(len(hk_new),1000)

Yhk_zp = np.fft.fft(hk_zp)

fig,ax = plt.subplots(1,2,figsize=(10,3))
ax[0].scatter(1/np.flip(freq_zp),np.abs(np.fft.fft(hk_new))**2,s=5)
#ax[0].vlines(1/s_freq,ymin=1e-3,ymax=1e4)
ax[0].set_yscale('log')
#ax[0].set_xscale('log')
#plt.show()
freq = np.fft.fftfreq(len(hk),dt)
ax[1].scatter(1/np.flip(freq),np.abs(np.fft.fft(hk))**2,s=5)
#ax[1].vlines(49266,ymin=ax[1].get_ylim()[0],ymax=ax[1].get_ylim()[1])
#ax[0].vlines(49266,ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].vlines(-1/np.array(s_arr),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(1/np.array(s_arr),ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[1].vlines(1/s_ex,ymin=ax[0].get_ylim()[0],ymax=ax[0].get_ylim()[1])
#ax[0].set_xlim(5e3,1e8)
ax[0].set_xlim(1e6,6e6)
ax[1].set_xlim(1e6,6e6)
ax[0].set_xlim(abs(1/g)-9e3,abs(1/g)+9e3)
ax[1].set_xlim(abs(1/g)-9e3,abs(1/g)+9e3)
ax[1].set_yscale('log')
#ax[1].set_xscale('log')
plt.show()

# %%
g_new = freq_zp(np.argmax(np.abs(Yhk_zp)**2))

s_idx = np.argmin(abs(freqs+1/45899))

# %%
half = int(len(pq)/2)
print(np.sort(np.abs(np.fft.fft(pq))[:half]**2)[-5:])
print(np.sort(np.abs(np.fft.fft(pq))[half:]**2)[-5:])
print(np.argsort(np.abs(np.fft.fft(pq))[:half]**2)[-5:])
print(np.argsort(np.abs(np.fft.fft(pq))[half:]**2)[-5:]+half)

print(1/freq[294])
print(1/freq[9803])
print(1/freq[9804])
print(1/s_freq)
print(1/np.array(s_arr))
print(1/np.array(g_arr))
print(1/49266)
print(1/50510)

print(1/g_arr[0])
print(1/(g_arr[3]-g_arr[5]))
print(1/(s_arr[0]-s_arr[4]))

# %%
'''
z1 = (g+s-g6-s6); z2 = (g+s-g5-s7); z3 = (g+s-g5-s6); z4 = (2*g6-g5); z5 = (2*g6-g7); z6 = (s-s6-g5+g6); z7 = (g-3*g6+2*g5)
        
z8 = (2*(g-g6)+s-s6); z9 = (3*(g-g6)+s-s6); z10 = ((g-g6)+s-s6)
    
z11 = g-2*g7+g6; z12 = 2*g-2*g5; z13 = -4*g+4*g7; z14 = -2*s-s6

if small_planets_flag:
        #freq1 = [(g1),(g2),(g3),(g4),(g5),(g6),(g7),(g8),z1,z2,z3,z4,z5,z7,z8,z9,g-z8,g-z9,g-z10,z11,z12,z13]
        #freq2 = [(s1),(s2),(s3),(s4),(s6),(s7),(s8),z1,z2,z3,z6,z8,z9,s-z8,s-z9,s-z10,z14]
    freq1 = [(g2),(g3),(g4),(g5),(g6),(g7),(g8),g-z8,g-z9,g-z10,z11,z12,z13,-g+2*s-g5]
    freq2 = [(s2),(s3),(s4),(s6),(s7),(s8),s-z8,s-z9,s-z10,z14,g-s+g5-s7,g+g5-2*s6,2*g-2*s6]
else:
    freq1 = [(g5),(g6),(g7),(g8),z1,z2,z3,z4,z5,z7,g-z8,g-z9,g-z10,z11,z12]
    freq2 = [(s6),(s7),(s8),z1,z2,z3,z6,z8,z9,s-z8,s-z9,s-z10,z14]
'''
g5 = g_arr[1]
g6 = g_arr[3]
g7 = g_arr[5]
g8 = g_arr[7]

s6 = s_arr[0]
s7 = s_arr[2]
s8 = s_arr[4]
de = np.array([s6-s8,g5-g6,s7-s6,s7+g5,s7+g6,+s6+g5,s6+g6,2*g5-g6,-g5+2*g6,g5+g6,-g5+s7,-g6+s7,-g5+s6,-g6+s6,g5-s7+s6, g5+s7-s6,g6-s7+s6,g6+s7-s6,2*s7,2*s6, s7+s6,-g5-+7,-g5+s6,-g6+s7,-g6+s6,-g5+2*s7,-g6+2*s7,-g5+2*s6,-g6+2*s6,-g5+s7+s6,-g6+s7+s6,2*s7-s6,-s7+2*s6,-g5+g6+s7,g5-g6+s7,-g5+s6+s6, g5-g6+s6,2*g5, 2*g6, g5+g6,2*g5-s7, 2*g5-s6,2*g6-s7, 2*g6-s6,g5+g6-s7, g5+g6-s6,2*g5,2*g6, 2*s7, 2*s6,2*g6-g7,3*g6-2*g5, 2*g6+s6,-g5+g6+g7,g5+g6-g7,-g5+2*g6+s6-s7,3*g6+s6])

g_ex = np.array([g5-g6,g5-g7,g5-g8,g6-g7,g6-g8,g7-g8])
s_ex = np.array([s6-s7,s6-s8,s7-s8])

print(1/de)

# %%
p_sat = np.sin(i_s)*np.sin(O_s)
q_sat = np.sin(i_s)*np.cos(O_s)

pq_sat = q_sat+1j*p_sat

freq = np.fft.fftfreq(len(pq_sat),dt)
plt.scatter(1/(freq),np.abs(np.fft.fft(pq_sat))**2,s=2)
plt.xscale('log')
plt.yscale('log')
sat_f = freq[np.argmax(np.abs(np.fft.fft(pq_sat))[1:]**2)+1]
print(sat_f,1/sat_f)
plt.vlines(1/sat_f,ymin=1e-5,ymax=1e4)
plt.show()
plt.xlim(1e4,1e5)

plt.scatter(1/np.flip(freq),np.abs(np.fft.fft(pq_sat))**2,s=2)
plt.xscale('log')
plt.yscale('log')

# %%
1/4e4

# %%
print(np.argmax(np.abs(np.fft.fft(hk))**2))
print(np.abs(np.fft.fft(hk))[9949]**2)
print(np.abs(np.fft.fft(hk_new))[9949]**2)
print(g)
print(freq)
prop_g = np.argmax(np.abs(np.fft.fft(hk_new))**2)
print(np.abs(np.fft.fft(hk))[prop_g]**2)
print(np.abs(np.fft.fft(hk_new))[prop_g]**2)
vals = np.sort(np.abs(np.fft.fft(pq_new))**2)[-5:]
print(np.sort(np.abs(np.fft.fft(pq_new))**2)[-5:])
idx = np.where(np.abs(np.fft.fft(pq_new))**2 == vals[-2])[0][0]
print(idx)
spec = np.abs(np.fft.fft(pq_new))**2
print(spec[idx-20:idx+21])

# %%
print(10*np.log10(5.11/1.4967e4))

# %%
fig,ax = plt.subplots(1,2,figsize=(10,3))
dt = 1000
freq = np.fft.fftfreq(len(hk_new),dt)
ax[0].scatter(1/np.flip(freq),np.abs(np.fft.fft(hk_new))**2,s=5)
ax[0].set_yscale('log')
ax[0].set_xscale('log')
#plt.show()
freq = np.fft.fftfreq(len(hk),dt)
ax[1].scatter(1/np.flip(freq),np.abs(np.fft.fft(hk))**2,s=5)
ax[1].set_yscale('log')
ax[1].set_xscale('log')
plt.show()

fig,ax = plt.subplots(1,2,figsize=(10,3))
freq = np.fft.fftfreq(len(hk_new),dt)
ax[0].scatter(1/(freq),np.abs(np.fft.fft(hk_new))**2,s=5)
ax[0].set_yscale('log')
ax[0].set_xscale('log')
#plt.show()
freq = np.fft.fftfreq(len(hk),dt)
ax[1].scatter(1/(freq),np.abs(np.fft.fft(hk))**2,s=5)
ax[1].set_yscale('log')
ax[1].set_xscale('log')
plt.show()

fig,ax = plt.subplots(1,2,figsize=(10,3))
freq = np.fft.fftfreq(len(pq_new),dt)
ax[0].scatter(1/(freq),np.abs(np.fft.fft(pq_new))**2,s=5)
ax[0].set_yscale('log')
ax[0].set_xscale('log')
#plt.show()
freq = np.fft.fftfreq(len(pq),dt)
ax[1].scatter(1/(freq),np.abs(np.fft.fft(pq))**2,s=5)
ax[1].set_yscale('log')
ax[1].set_xscale('log')
plt.show()

fig,ax = plt.subplots(1,2,figsize=(10,3))
freq = np.fft.fftfreq(len(pq_new),dt)
ax[0].scatter(1/np.flip(freq),np.abs(np.fft.fft(pq_new))**2,s=5)
ax[0].set_yscale('log')
ax[0].set_xscale('log')
#plt.show()
freq = np.fft.fftfreq(len(pq),dt)
ax[1].scatter(1/np.flip(freq),np.abs(np.fft.fft(pq))**2,s=5)
ax[1].set_yscale('log')
ax[1].set_xscale('log')
plt.show()

# %%
planets = ['Jupiter','Saturn','Uranus','Neptune','Venus','Earth','Mars']
colors = ['orange','blue','red','brown','green','magenta','violet']
print(1/np.array(g_arr),1/np.array(s_arr))

ls = (0, (5, 3, 1, 3))
#ls = (0, (1,5))

hk = hk_arr
pq = pq_arr


fig,ax = plt.subplots(2,2,figsize=(15,7),sharex=True)
ax=ax.flatten()
dt = 1000
freq = np.fft.fftfreq(len(hk_new),dt)
ax[0].scatter(1/np.flip(freq),np.abs(np.fft.fft(hk))**2,s=5)
ax[0].set_yscale('log')
ax[0].set_xscale('log')

lines2 = []
for i in range(len(planets)):
    ax[0].vlines(-1/np.array(g_arr[i]),ymin=np.min(np.abs(np.fft.fft(hk))**2),ymax=np.max(np.abs(np.fft.fft(hk))**2),label=planets[i],colors=colors[i],alpha=0.95,linestyle=ls)
    #line2.append(line)
ax[0].vlines(-1/np.array(g[0]),ymin=np.min(np.abs(np.fft.fft(hk))**2),ymax=np.max(np.abs(np.fft.fft(hk))**2),label='Proserpina',colors='gray',alpha=0.95,linestyle=ls)
#line2.append(line)
#plt.show()
fig.subplots_adjust(hspace=0,wspace=0)
freq = np.fft.fftfreq(len(hk),dt)
ax[1].scatter(1/(freq),np.abs(np.fft.fft(pq))**2,s=5)
ax[1].set_yscale('log')
ax[1].set_xscale('log')
#planets = ['Venus','Earth','Mars','Saturn','Uranus','Neptune']
j=0
for i in range(len(planets)):
    if i == 0:
        continue
    ax[1].vlines(np.abs(1/np.array(s_arr[j])),ymin=np.min(np.abs(np.fft.fft(pq))**2),ymax=np.max(np.abs(np.fft.fft(pq))**2),label=planets[i],colors=colors[i],alpha=0.95,linestyle=ls)
    j=j+1
print(1/s_freq)
ax[1].vlines(abs(1/np.array(s_freq[0])),ymin=np.min(np.abs(np.fft.fft(pq))**2),ymax=np.max(np.abs(np.fft.fft(pq))**2),label='Proserpina',colors=['gray'],alpha=0.95,linestyle=ls)
#ax[1].legend(loc='upper left')
ax[0].set_xlim(2000,1e7)
#ax[0].set_ylim(1e-3,2e6)
#plt.show()

#fig,ax = plt.subplots(2,figsize=(7,6),sharex=True)
dt = 1000
freq = np.fft.fftfreq(len(hk_new),dt)
ax[2].scatter(1/np.flip(freq),np.abs(np.fft.fft(hk_new))**2,s=5)
ax[2].set_yscale('log')
ax[2].set_xscale('log')
'''
for i in range(len(planets)):
    ax[2].vlines(-1/np.array(g_arr[i]),ymin=np.min(np.abs(np.fft.fft(hk_new))**2),ymax=np.max(np.abs(np.fft.fft(hk_new))**2),label=planets[i],colors=colors[i],alpha=0.95,linestyle=ls)
#ax[2].legend(loc='upper left')
'''
ax[2].vlines(-1/np.array(g),ymin=np.min(np.abs(np.fft.fft(hk_new))**2),ymax=np.max(np.abs(np.fft.fft(hk_new))**2),label='Proserpina',colors='gray',alpha=0.95,linestyle=ls)

#plt.show()
fig.subplots_adjust(hspace=0)
freq = np.fft.fftfreq(len(hk),dt)
ax[3].scatter(1/(freq),np.abs(np.fft.fft(pq_new))**2,s=5)
ax[3].set_yscale('log')
ax[3].set_xscale('log')
#planets = ['Venus','Earth','Mars','Saturn','Uranus','Neptune']
j=0
'''
for i in range(len(planets)):
    if i == 3:
        continue
    ax[3].vlines(1/np.array(s_arr[j]),ymin=np.min(np.abs(np.fft.fft(pq_new))**2),ymax=np.max(np.abs(np.fft.fft(pq_new))**2),label=planets[i],colors=colors[i],alpha=0.95,linestyle=ls)
    j=j+1
'''
print(1/s_freq)
ax[3].vlines(abs(1/np.array(s_freq)),ymin=np.min(np.abs(np.fft.fft(pq_new))**2),ymax=np.max(np.abs(np.fft.fft(pq_new))**2),label='Proserpina',colors=['gray'],alpha=0.95,linestyle=ls)
#ax[1].legend(loc='upper left')
ax[2].set_xlim(2000,1e7)
#ax[2].set_ylim(np.min(np.abs(np.fft.fft(hk_new))**2)*0.2,np.max(np.abs(np.fft.fft(hk_new))**2)*2)
fig.suptitle('Asteroid (46) Proserpina Ecc and Sin(Inc) Power Spectrum',fontsize=15)
ax[0].set_ylabel('Unfiltered Power')
ax[0].set_title('Ecc Power Spectrum')
ax[1].set_title('Sin(Inc) Power Spectrum')
ax[0].legend(loc='upper left',fontsize='medium')
ax[2].set_ylabel('Filtered Power')
ax[2].set_xlabel('Period (years)')
ax[3].set_xlabel('Period (years)')
#ax[2].yaxis.grid(True, which='major')
ax[2].minorticks_off()
plt.savefig('powerspectrum.pdf')
plt.savefig('powerspectrum.png')
plt.show()
# Out:
# [ -303106.32204625   -45877.10972599  -417092.84165969 -1991040.03530929
#   -180968.58776188   -73723.92329123   -75613.12826424    54059.34213196
#  -1109109.02110197  -357535.85428587   -51546.88343371   -46959.13178652
#   -527621.60607164   -24816.63421699   -24273.50748644   -17008.6125307
#     58815.68543229   -22938.55486299] [   49223.23566344   434743.49988118  1942225.17498336    69859.13851656
#     73161.72492263   209055.6295226     55508.05945629    50503.17462117
#    560119.425712      25764.03295088   -11872.82640432  -303106.32204625
#    -45877.10972599  -417092.84165969 -1991040.03530929]
# [  26462.71980197   13231.35990098    8820.90660066  -22050.5127358
#   -11025.2563679   -12027.98720046   -7782.71594835   -8269.35330254
#    -6013.99360023 -132250.4885348 ]
# [  26462.71980197   13231.35990098    8820.90660066  -22050.5127358
#   -11025.2563679   -12027.98720046   -7782.71594835   -8269.35330254
#    -6013.99360023 -132250.4885348 ]

# %%
fig,ax = plt.subplots(2,2,figsize=(15,7),sharex=True)
ax=ax.flatten()
dt = 1000
freq = np.fft.fftfreq(len(hk_new),dt)
ax[0].scatter(-1/np.flip(freq),np.abs(np.fft.fft(hk))**2,s=5)
ax[0].set_yscale('log')
ax[0].set_xscale('log')

lines2 = []
for i in range(len(planets)):
    ax[0].vlines(-1/np.array(g_arr[i]),ymin=np.min(np.abs(np.fft.fft(hk))**2),ymax=np.max(np.abs(np.fft.fft(hk))**2),label=planets[i],colors=colors[i],alpha=0.95,linestyle=ls)
    #line2.append(line)
ax[0].vlines(-1/np.array(g[0]),ymin=np.min(np.abs(np.fft.fft(hk))**2),ymax=np.max(np.abs(np.fft.fft(hk))**2),label='Proserpina',colors='gray',alpha=0.95,linestyle=ls)
#line2.append(line)
#plt.show()
fig.subplots_adjust(hspace=0,wspace=0)
freq = np.fft.fftfreq(len(hk),dt)
ax[1].scatter(-1/(freq),np.abs(np.fft.fft(pq))**2,s=5)
ax[1].set_yscale('log')
ax[1].set_xscale('log')
#planets = ['Venus','Earth','Mars','Saturn','Uranus','Neptune']
j=0
for i in range(len(planets)):
    if i == 0:
        continue
    ax[1].vlines(np.abs(1/np.array(s_arr[j])),ymin=np.min(np.abs(np.fft.fft(pq))**2),ymax=np.max(np.abs(np.fft.fft(pq))**2),label=planets[i],colors=colors[i],alpha=0.95,linestyle=ls)
    j=j+1
print(1/s_freq)
ax[1].vlines(abs(1/np.array(s_freq[0])),ymin=np.min(np.abs(np.fft.fft(pq))**2),ymax=np.max(np.abs(np.fft.fft(pq))**2),label='Proserpina',colors=['gray'],alpha=0.95,linestyle=ls)
#ax[1].legend(loc='upper left')
ax[0].set_xlim(2000,1e7)
#ax[0].set_ylim(1e-3,2e6)
#plt.show()

#fig,ax = plt.subplots(2,figsize=(7,6),sharex=True)
dt = 1000
freq = np.fft.fftfreq(len(hk_new),dt)
ax[2].scatter(-1/np.flip(freq),np.abs(np.fft.fft(hk_new))**2,s=5)
ax[2].set_yscale('log')
ax[2].set_xscale('log')
'''
for i in range(len(planets)):
    ax[2].vlines(-1/np.array(g_arr[i]),ymin=np.min(np.abs(np.fft.fft(hk_new))**2),ymax=np.max(np.abs(np.fft.fft(hk_new))**2),label=planets[i],colors=colors[i],alpha=0.95,linestyle=ls)
#ax[2].legend(loc='upper left')
'''
ax[2].vlines(-1/np.array(g),ymin=np.min(np.abs(np.fft.fft(hk_new))**2),ymax=np.max(np.abs(np.fft.fft(hk_new))**2),label='Proserpina',colors='gray',alpha=0.95,linestyle=ls)

#plt.show()
fig.subplots_adjust(hspace=0)
freq = np.fft.fftfreq(len(hk),dt)
ax[3].scatter(-1/(freq),np.abs(np.fft.fft(pq_new))**2,s=5)
ax[3].set_yscale('log')
ax[3].set_xscale('log')
#planets = ['Venus','Earth','Mars','Saturn','Uranus','Neptune']
j=0
'''
for i in range(len(planets)):
    if i == 3:
        continue
    ax[3].vlines(1/np.array(s_arr[j]),ymin=np.min(np.abs(np.fft.fft(pq_new))**2),ymax=np.max(np.abs(np.fft.fft(pq_new))**2),label=planets[i],colors=colors[i],alpha=0.95,linestyle=ls)
    j=j+1
'''
print(1/s_freq)
ax[3].vlines(abs(1/np.array(s_freq)),ymin=np.min(np.abs(np.fft.fft(pq_new))**2),ymax=np.max(np.abs(np.fft.fft(pq_new))**2),label='Proserpina',colors=['gray'],alpha=0.95,linestyle=ls)
#ax[1].legend(loc='upper left')
ax[2].set_xlim(2000,1e7)
#ax[2].set_ylim(np.min(np.abs(np.fft.fft(hk_new))**2)*0.2,np.max(np.abs(np.fft.fft(hk_new))**2)*2)
fig.suptitle('Asteroid (46) Proserpina Ecc and Sin(Inc) Power Spectrum',fontsize=15)
ax[0].set_ylabel('Unfiltered Power')
ax[0].set_title('Ecc Power Spectrum')
ax[1].set_title('Sin(Inc) Power Spectrum')
ax[0].legend(loc='upper left',fontsize='medium')
ax[2].set_ylabel('Filtered Power')
ax[2].set_xlabel('Period (years)')
ax[3].set_xlabel('Period (years)')
#ax[2].yaxis.grid(True, which='major')
ax[2].minorticks_off()
plt.savefig('powerspectrum_neg.pdf')
plt.savefig('powerspectrum_neg.png')
plt.show()
# Out:
# [  26462.71980197   13231.35990098    8820.90660066  -22050.5127358
#   -11025.2563679   -12027.98720046   -7782.71594835   -8269.35330254
#    -6013.99360023 -132250.4885348 ]
# [  26462.71980197   13231.35990098    8820.90660066  -22050.5127358
#   -11025.2563679   -12027.98720046   -7782.71594835   -8269.35330254
#    -6013.99360023 -132250.4885348 ]

# %%
ecc = np.abs(hk_arr)

pe_ecc = np.mean(ecc)
ds = int(len(ecc)/(windows+1))
eccs = np.zeros(5)
for i in range(5):
    eccs[i] = np.mean(ecc[ds*i::ds*(i+2)])
print(pe_ecc)
print(eccs)
print(np.std(eccs))
print(np.sqrt(np.mean(pe_ecc-eccs)**2))

plt.plot(ecc)

# %%
print(data)
print(errs)
print(rms)
#0.15259303272252095 0.09363146848428758
#[0.15287758 0.14960828 0.15308562 0.15268463 0.14985997]
#[0.09487692 0.09203602 0.09468647 0.09428538 0.09227871]

# %%
def to_equinoctial(e,i,o,O):
    h = e*np.sin(o+O)
    k = e*np.cos(o+O)
    p = i*np.sin(O)
    q = i*np.cos(O)
    
    return h,k,p,q

import tools
time_run = s[-1].t
flag, a_init, e_init, inc_init, lan_init, aop_init, M_init, t_init = tools.read_sa_for_sbody(des = str(objname), archivefile=fullfile,clones=0,tmin=time_run,tmax=0,center='helio')
ecc_ast = e_init
inc_ast = np.sin(inc_init)
omega_ast = aop_init
Omega_ast = lan_init
time = t_init

freqs_kh = g_arr
freqs_pq = s_arr
print(freqs_kh,freqs_pq)
h_ast, k_ast, p_ast, q_ast = to_equinoctial(ecc_ast, inc_ast, omega_ast, Omega_ast)

hk_ast = k_ast+1j*h_ast
pq_ast = q_ast+1j*p_ast

# %%
import numpy as np
from scipy.fft import fft, ifft, fftfreq
from scipy.ndimage import convolve1d, gaussian_filter1d

def smooth_fft_convolution(fft_signal, freqs, primary_freqs, protect_radius_bins=3, kernel_size=15, method="gaussian"):
    """
    Fast convolutional smoothing of FFT log-power spectrum, excluding primary peaks.
    """
    fft_signal = np.asarray(fft_signal)
    log_power = 10 * np.log10(np.abs(fft_signal)**2 + 1e-12)
    phase = np.angle(fft_signal)

    N = len(fft_signal)
    mask = np.ones(N, dtype=bool)
    
    # Mask protected bins around each primary frequency
    for pf in primary_freqs:
        idx = np.argmin(np.abs(freqs - pf))
        start = max(idx - protect_radius_bins, 0)
        end = min(idx + protect_radius_bins + 1, N)
        mask[start:end] = False
    peak = log_power[idx]
    # Prepare data and mask for convolution
    masked_log_power = log_power.copy()
    masked_log_power[~mask] = 0  # zero out protected region before smoothing
    mask_float = mask.astype(float)

    # Convolve both signal and mask to normalize after convolution
    if method == "gaussian":
        smoothed_log_power = gaussian_filter1d(masked_log_power, sigma=kernel_size, mode="mirror")
        smoothed_mask = gaussian_filter1d(mask_float, sigma=kernel_size, mode="mirror")
    else:  # fallback to uniform boxcar
        kernel = np.ones(kernel_size) / kernel_size
        smoothed_log_power = convolve1d(masked_log_power, kernel, mode="nearest")
        smoothed_mask = convolve1d(mask_float, kernel, mode="nearest")

    # Normalize result: divide smoothed signal by smoothed mask
    #smoothed_mask[int(N/2)-3:int(N/2)+3] = 1
    #smoothed_mask[N-6:int(N)-1] = 0
    #smoothed_mask[0] = 0
    with np.errstate(invalid='ignore', divide='ignore'):
        
        normalized_log_power = np.where(smoothed_mask > 1e-6 , smoothed_log_power / smoothed_mask, log_power)

    # Restore original log_power in protected regions
    
    #normalized_log_power[normalized_log_power > 1e-5*np.max(log_power)] = 1e-3*np.max(log_power)
    normalized_log_power[~mask] = log_power[~mask]
    
    

    # Back to magnitude
    magnitude = 10 ** (0.5 * normalized_log_power / 10)

    # Normalize power to match original
    orig_power = np.sum(np.abs(fft_signal)**2)
    new_power = np.sum(magnitude**2)
    scale = np.sqrt(orig_power / new_power)

    smoothed_fft = magnitude * np.exp(1j * phase) * scale
    #smoothed_fft[idx] = np.median(smoothed_fft[idx-1:idx+2])
    #smoothed_fft[idx] = 0
    
    scaling_factor = np.sqrt(1/(np.max(np.abs(smoothed_fft)**2) / np.max(np.abs(fft_signal)**2)))
    #scaling_factor=1
    #smoothed_fft[0] = np.median(smoothed_fft[1:10])
    return smoothed_fft * scaling_factor

def extract_proper_mode(signal, time, known_planet_freqs, freq_tol=5e-6, protect_bins=15,kernel=60, inc_filt = False):
    """
    Extract the 'free' (proper) frequency from an asteroid signal by:
    1. Identifying frequencies not associated with planetary forcing.
    2. Filtering all but the closest match in frequency space (band-pass).
    
    Parameters:
    - signal: array-like, real or complex signal (e.g., k + i*h or q + i*p)
    - time: array-like, same length as signal, evenly spaced time values
    - known_planet_freqs: list of planetary secular frequencies to remove (in same units as 1/time)
    - freq_tol: float, tolerance for deciding if a frequency matches a known planetary mode
    - keep_width: float, half-width of the frequency band to preserve around the free frequency
    
    Returns:
    - proper_signal: the filtered signal with only the proper mode preserved
    - proper_freq: the frequency identified as the free/proper mode
    """
    N = len(signal)
    dt = np.abs(time[1] - time[0])
    freqs = fftfreq(N, d=dt)
    spectrum = np.fft.fft(signal)

    if inc_filt:
        spectrum[0] = 0
    # Find the frequency with the highest power that is NOT near any planetary frequency
    power = np.abs(spectrum)**2
    sorted_indices = np.argsort(power)[::-1]  # sort descending by power
    
    proper_freq = None
    for idx in sorted_indices:
        f = freqs[idx]
        if all(np.abs(f - pf) > freq_tol for pf in known_planet_freqs):
            proper_freq = f
            break

    if proper_freq is None:
        raise ValueError("No proper (free) frequency found distinct from planetary modes.")

    '''
    plt.scatter(1/freqs,power,s=10)
    plt.vlines(1/proper_freq,ymin=1e-2,ymax=1e6,colors='r')
    plt.xscale('log')
    plt.yscale('log')
    plt.show()
    '''
    
    filt_signal = smooth_fft_convolution(spectrum, freqs, [proper_freq], 
                                         protect_radius_bins=protect_bins, 
                                         kernel_size=kernel, 
                                         method="gaussian")
    '''plt.scatter(1/freqs,np.abs(filt_signal)**2,s=10)
    plt.vlines(1/proper_freq,ymin=1e-2,ymax=1e6,colors='r')
    plt.xscale('log')
    plt.yscale('log')
    plt.show()'''
    # Build a band-pass filter centered on the proper frequency
    #mask = np.abs(freqs - proper_freq) < keep_width
    #filtered_spectrum = np.zeros_like(spectrum)
    #filtered_spectrum[mask] = spectrum[mask]

    # Inverse FFT to get the filtered signal
    proper_signal = np.fft.ifft(filt_signal)

    return proper_signal, proper_freq


# time and signal must be real or complex numpy arrays of equal length
# known_planet_freqs is a list like: [g6, g7, g8, ...]
dt = np.abs(time[1]-time[0])
kernel=20*int(dt/100)
protect = 50*int(dt/100)
per_shave = 0.2
#print(data[-5],data[-4])
proper_hk, g_proper = extract_proper_mode(hk_ast, t_init, known_planet_freqs=g_arr, protect_bins=protect,kernel=kernel)
proper_pq, s_proper = extract_proper_mode(pq_ast, t_init, known_planet_freqs=s_arr, protect_bins=protect,kernel=kernel, inc_filt=True)

ecc_proper = np.abs(proper_hk)
sini_proper = np.abs(proper_pq)

windows = 5
error_a = np.zeros(windows)
error_e = np.zeros(windows)
error_sini = np.zeros(windows)
ds = int(len(hk_ast)/(windows+1))
dt = 100
for j in range(windows):
    hk_win = hk_ast[j*ds:(2+j)*ds]
    pq_win = pq_ast[j*ds:(2+j)*ds]    
    tin = t_init[j*ds:(2+j)*ds]   
    
    proper_hk_win, g_proper_win = extract_proper_mode(hk_win, tin, known_planet_freqs=g_arr, protect_bins=protect,kernel=kernel)
    proper_pq_win, s_proper_win = extract_proper_mode(pq_win, tin, known_planet_freqs=s_arr, protect_bins=protect,kernel=kernel, inc_filt=True)
    
    if j == 1:
        plt.plot(hk_win)
        plt.plot((proper_hk_win))
        plt.title('hk_win')
        plt.show()
        plt.plot(np.abs(hk_win))
        plt.plot(np.abs(proper_hk_win))
        plt.title('ecc')
        plt.show()
        plt.plot(pq_win)
        plt.plot((proper_pq_win))
        plt.title('pq_win')
        plt.show()
        plt.plot(np.abs(pq_win))
        plt.plot(np.abs(proper_pq_win))
        plt.title('inc')
        plt.show()
    Nn = len(proper_hk_win)
    #error_e[j] = np.nanmean(np.abs(proper_hk_win))
    #error_sini[j] = np.nanmean(np.abs(proper_pq_win))
    error_a[j] = np.nanmean(a_init[j*ds:(2+j)*ds])
    error_e[j] = np.nanmean(np.abs(proper_hk_win)[int(Nn*per_shave):int(Nn*(1-per_shave))])
    error_sini[j] = np.nanmean(np.abs(proper_pq_win)[int(Nn*per_shave):int(Nn*(1-per_shave))])
    #error_e[j] = np.mean(np.abs(proper_hk_win[j*ds:(2+j)*ds]))
    #error_sini[j] = np.mean(np.abs(proper_pq_win[j*ds:(2+j)*ds]))
    
    '''fig,ax = plt.subplots(1,2,figsize=(10,4))
    ax[0].plot(np.abs(proper_hk_win))
    ax[0].plot(np.abs(hk_win),alpha=0.25)
    ax[1].plot(np.abs(proper_pq_win))
    ax[1].plot(np.abs(pq_win),alpha=0.25)
    fig.suptitle('Proper Ecc and SinI')
    plt.show()
    '''
# Extract components
N = len(ecc_proper)


fig,ax = plt.subplots(1,2,figsize=(10,4))
ax[0].plot(ecc_proper)
ax[1].plot(sini_proper)
fig.suptitle('Proper + Forced E and SinI')
#plt.show()

#fig,ax = plt.subplots(1,2,figsize=(10,4))
ax[0].plot(np.abs(hk_ast),alpha=0.3)
ax[1].plot(np.abs(pq_ast),alpha=0.3)

ax[0].vlines([N*0.1,N*0.2,N*0.8,N*0.9],ymin=np.min(np.abs(hk_ast)),ymax=np.max(np.abs(hk_ast)))
ax[1].vlines([N*0.1,N*0.2,N*0.8,N*0.9],ymin=np.min(np.abs(pq_ast)),ymax=np.max(np.abs(pq_ast)))
fig.suptitle('Forced E and SinI')
plt.show()
N = len(ecc_proper)
print(np.mean(ecc_proper[int(N*(per_shave)):int(N*(1-per_shave))]),np.mean(sini_proper[int(N*per_shave):int(N*(1-per_shave))]))
print(np.mean(ecc_proper),np.mean(sini_proper))
print(np.mean(np.abs(hk_ast)),np.mean(np.abs(pq_ast)))

print(np.sqrt(np.nanmean((np.nanmean(ecc_proper[int(N*per_shave):int(N*(1-per_shave))])-error_e)**2)))
print(np.sqrt(np.nanmean((np.nanmean(sini_proper[int(N*per_shave):int(N*(1-per_shave))])-error_sini)**2)))

print(np.sqrt(np.nanmean((np.nanmean(ecc_proper)-error_e)**2)))
print(np.sqrt(np.nanmean((np.nanmean(sini_proper)-error_sini)**2)))

print(g_arr)
print(s_arr)

# %%
np.set_printoptions(precision=20, suppress=True)
print(error_sini)
print(errs)
print(data)
print(np.mean(ecc_proper[int(N*(per_shave)):int(N*(1-per_shave))]),np.mean(sini_proper[int(N*per_shave):int(N*(1-per_shave))]))

pes = np.array([np.mean(a_init),np.mean(ecc_proper[int(N*(per_shave)):int(N*(1-per_shave))]),np.mean(sini_proper[int(N*per_shave):int(N*(1-per_shave))])]).T

print(len(errs),len(errs[0]))
#print(len(errs),len(errs[0]))

print(np.sqrt(np.mean((data-errs)**2,axis=0)))
print(np.sqrt(np.mean((pes-np.array([error_a,error_e,error_sini]).T)**2,axis=0)))

print(error_e-errs[:,1])
print(error_sini-errs[:,2])

print(pes[-1]-data[-1])

# %%
print(dt)

# %%
kernel=5
protect = 25
per_shave = 0.2
#print(data[-5],data[-4])
proper_hk, g_proper = extract_proper_mode(hk_ast, time, known_planet_freqs=g_arr, protect_bins=protect,kernel=kernel)
proper_pq, s_proper = extract_proper_mode(pq_ast, time, known_planet_freqs=s_arr,protect_bins=protect,kernel=kernel, inc_filt = True)

ecc_proper = np.abs(proper_hk)
sini_proper = np.abs(proper_pq)

windows = 5
error_e = np.zeros(windows)
error_sini = np.zeros(windows)
ds = int(len(hk_ast)/(windows+1))
dt = 100
for j in range(windows):
    hk_win = hk_ast[j*ds:(2+j)*ds]
    pq_win = pq_ast[j*ds:(2+j)*ds]

    freqs = np.fft.fftfreq(len(hk_win),d=dt)
    
    
    proper_hk_win, g_proper_win = extract_proper_mode(hk_win, time[j*ds:(2+j)*ds], known_planet_freqs=g_arr, protect_bins=protect,kernel=kernel)
    proper_pq_win, s_proper_win = extract_proper_mode(pq_win, time[j*ds:(2+j)*ds], known_planet_freqs=s_arr, protect_bins=protect,kernel=kernel, inc_filt = True)
    
    if j == 1:
        plt.plot(pq_win)
        plt.plot((proper_pq_win))
        plt.title('pq_win')
        plt.show()
    if j == 1:
        plt.plot(np.abs(pq_win))
        plt.plot(np.abs(proper_pq_win))
        plt.title('Inc')
        plt.show()
    Nn = len(proper_hk_win)
    #error_e[j] = np.nanmean(np.abs(proper_hk_win))
    #error_sini[j] = np.nanmean(np.abs(proper_pq_win))
    error_e[j] = np.nanmedian(np.abs(proper_hk_win)[int(Nn*per_shave):int(Nn*(1-per_shave))])
    error_sini[j] = np.nanmedian(np.abs(proper_pq_win)[int(Nn*per_shave):int(Nn*(1-per_shave))])
    #error_e[j] = np.mean(np.abs(proper_hk_win[j*ds:(2+j)*ds]))
    #error_sini[j] = np.mean(np.abs(proper_pq_win[j*ds:(2+j)*ds]))
    
    '''fig,ax = plt.subplots(1,2,figsize=(10,4))
    ax[0].plot(np.abs(proper_hk_win))
    ax[0].plot(np.abs(hk_win),alpha=0.25)
    ax[1].plot(np.abs(proper_pq_win))
    ax[1].plot(np.abs(pq_win),alpha=0.25)
    fig.suptitle('Proper Ecc and SinI')
    plt.show()
    '''
# Extract components
N = len(ecc_proper)


fig,ax = plt.subplots(1,2,figsize=(10,4))
ax[0].plot(ecc_proper)
ax[1].plot(sini_proper)
fig.suptitle('Proper + Forced E and SinI')
#plt.show()

#fig,ax = plt.subplots(1,2,figsize=(10,4))
ax[0].plot(np.abs(hk_ast),alpha=0.3)
ax[1].plot(np.abs(pq_ast),alpha=0.3)

ax[0].vlines([N*0.1,N*0.2,N*0.8,N*0.9],ymin=np.min(np.abs(hk_ast)),ymax=np.max(np.abs(hk_ast)))
ax[1].vlines([N*0.1,N*0.2,N*0.8,N*0.9],ymin=np.min(np.abs(pq_ast)),ymax=np.max(np.abs(pq_ast)))
fig.suptitle('Forced E and SinI')
plt.show()

print(np.median(ecc_proper[int(N*(per_shave)):int(N*(1-per_shave))]),np.mean(sini_proper[int(N*per_shave):int(N*(1-per_shave))]))
print(np.median(ecc_proper),np.median(sini_proper))
print(np.median(np.abs(hk_ast)),np.median(np.abs(pq_ast)))

print(np.sqrt(np.nanmean((np.nanmedian(ecc_proper[int(N*per_shave):int(N*(1-per_shave))])-error_e)**2)))
print(np.sqrt(np.nanmean((np.nanmedian(sini_proper[int(N*per_shave):int(N*(1-per_shave))])-error_sini)**2)))

print(np.sqrt(np.nanmean((np.nanmedian(ecc_proper)-error_e)**2)))
print(np.sqrt(np.nanmean((np.nanmedian(sini_proper)-error_sini)**2)))

print(g_arr)
print(s_arr)

# %%
print(data)
print(error_e)
print(error_sini)
print(errs)
print(rms)

print(np.sqrt(np.nanmean((np.nanmean(ecc_proper)-error_e)**2)))
print(np.sqrt(np.nanmean((np.nanmean(sini_proper)-error_sini)**2)))

#data,errs,rms,g_arr,s_arr = prop_elem.prop_calc(objname,filename,windows,True)
#print(data,errs,rms)
#print(g_arr)
#print(s_arr)

# %%
print(len(s[0].particles))
print(s[-1].t)

print(astdys.iloc[2194])

# %% [markdown]
# Object #48
# e           6.364700e-02
# sini        1.150350e-01
# rms_e       7.600000e-07
# rms_sini    6.100000e-07
#
# ObsEcc           0.067524
# ObsSin(Inc)      0.117086
# PropEcc          0.063675
# PropSin(Inc)     0.114994
#
# Object #5593
# e           1.488400e-01
# rms_e       4.900000e-05
# sini        9.541100e-02
# rms_sini    5.500000e-05
#
# ObsEcc             0.157483
# ObsSin(Inc)        0.098935
# PropEcc            0.152569
# PropSin(Inc)       0.093803
# RMS_err_e          0.004116
# RMS_err_sinI       0.002455
#
# Object #2293
# PES: [3.13817718 0.1547783  0.03530461]
# Errs: [0.0001772  0.00039198 0.00547022]
#
# sma            3.138094
# rms_sma        0.000095
# e              0.155172
# rms_e          0.000180
# sini           0.021168
# rms_sini       0.000002

# %%
import pandas as pd

pe = pd.read_csv('../data/results/NesvornyAst_100yr_prop_elem_multi_5win_helio_check9000.csv')
#pe = pd.read_csv('../data/results/NesvornyAst_100yr_prop_elem_multi_5win_helio_test.csv')
ind = np.where(pe['RMS_err_e'] < 1)[0]

pe2 = pd.read_csv('../data/results/NesvornyAst_100yr_prop_elem_multi_5win_helio_100yr.csv')
pe2 = pd.read_csv('../data/data_files/NesvornyAst_100yr.csv')

print(np.nanmean(pe['RMS_err_e'].iloc[ind]))
print(np.nanmean(pe['RMS_err_sinI'].iloc[ind]))

#print(np.mean(pe2['RMS_err_e'].iloc[9000:9100]))
#print(np.mean(pe2['RMS_err_sinI'].iloc[9000:9100]))

print(np.nanmean(pe2['rms_e'].iloc[9000:9100]))
print(np.nanmean(pe2['rms_sini'].iloc[9000:9100]))

print(np.nanmedian(pe['RMS_err_e'].iloc[ind]))
print(np.nanmedian(pe['RMS_err_sinI'].iloc[ind]))

#print(np.nanmedian(pe2['RMS_err_e'].iloc[9000:9100]))
#print(np.nanmedian(pe2['RMS_err_sinI'].iloc[9000:9100]))

print(np.nanmedian(pe2['rms_e'].iloc[9000:9100]))
print(np.nanmedian(pe2['rms_sini'].iloc[9000:9100]))

#plt.plot(pe['RMS_err_e'])
#plt.show()
#plt.plot(pe2['RMS_err_e'].iloc[9000:9100])
#plt.show()

plt.plot(pe['RMS_err_e'].iloc[ind])
plt.show()
plt.plot(pe2['rms_e'].iloc[9000:9100],alpha=0.3)
plt.show()

#plt.plot(pe['RMS_err_sinI'])
#plt.show()
#plt.plot(pe2['RMS_err_sinI'].iloc[9000:9100])
#plt.show()

plt.plot(pe['RMS_err_sinI'].iloc[ind])
plt.show()
plt.plot(pe2['rms_sini'].iloc[9000:9100],alpha=0.3)
plt.show()

# %%
print(np.mean(pe['RMS_err_a']))

#print(np.mean(pe2['RMS_err_e'].iloc[9000:9100]))
#print(np.mean(pe2['RMS_err_sinI'].iloc[9000:9100]))

print(np.mean(pe2['rms_sma'].iloc[9000:9100]))

pe2 = pd.read_csv('../data/results/NesvornyAst_100yr_prop_elem_multi_5win_helio_100yr.csv')

print(np.mean(pe2['RMS_err_a']))

# %%
ind = np.where(pe['RMS_err_e'] < 0.01)[0]
ind2 = np.where(pe['RMS_err_sinI'] < 0.01)[0]
ind = np.intersect1d(ind,ind2)
plt.hist(pe['RMS_err_e'].iloc[ind],bins=1000)
plt.xscale('log')
plt.show()
plt.hist(pe['RMS_err_sinI'].iloc[ind],bins=1000)
plt.xscale('log')
plt.show()
'''
ind = np.where(pe2['RMS_err_e'] < 1)
plt.hist(pe2['RMS_err_e'].iloc[ind],bins=1000)
plt.xscale('log')
plt.show()
plt.hist(pe2['RMS_err_sinI'],bins=2000)
plt.xscale('log')
plt.show()
'''
pe2 = pd.read_csv('../data/data_files/NesvornyAst_100yr.csv')
ind = np.where(pe2['rms_e'] < 0.001)
ind2 = np.where(pe2['rms_sini'] < 0.001)[0]
ind = np.intersect1d(ind,ind2)

plt.hist(pe2['rms_e'].iloc[9000:9100],bins=1000)
plt.xscale('log')
plt.show()
plt.hist(pe2['rms_sini'].iloc[9000:9100],bins=1000)
plt.xscale('log')
plt.show()

# %%
print(pe.iloc[5312])

# %% [markdown]
# Unnamed: 0      5312.000000
# Objname         5593.000000
# ObsSMA             2.271014
# ObsEcc             0.157483
# ObsSin(Inc)        0.098935
# PropSMA            2.271014
# PropEcc            0.152569
# PropSin(Inc)       0.093803
# 0_2PE_a            2.271009
# 0_2PE_e            0.154590
# 0_2PE_sinI         0.092340
# 1_3PE_a            2.270863
# 1_3PE_e            0.153862
# 1_3PE_sinI         0.094777
# 2_4PE_a            2.270933
# 2_4PE_e            0.158667
# 2_4PE_sinI         0.097482
# 3_5PE_a            2.271076
# 3_5PE_e            0.158794
# 3_5PE_sinI         0.097371
# 4_6PE_a            2.271101
# 4_6PE_e            0.154300
# 4_6PE_sinI         0.094677
# RMS_err_a          0.000090
# RMS_err_e          0.004116
# RMS_err_sinI       0.002455
# Delta_a            0.000087
# Delta_e            0.006225
# Delta_sinI         0.003680

# %%
ej = np.zeros(len(s))
es = np.zeros(len(s))
en = np.zeros(len(s))
an = np.zeros(len(s))
ep = np.zeros(len(s))
ap = np.zeros(len(s))
t = np.zeros(len(s))
for i in range(len(s)):
    ej[i] = s[i].particles[4].e
    es[i] = s[i].particles[5].e
    en[i] = s[i].particles[7].e
    an[i] = s[i].particles[7].a
    ep[i] = s[i].particles[8].e
    ap[i] = s[i].particles[8].a
    t[i] = s[i].t

plt.scatter(t,ej)
plt.show()
plt.scatter(t,es)
plt.show()
plt.scatter(t,en)
plt.show()

# %% [raw]
# plt.scatter(1/freqs,np.abs(np.fft.fft(ej))**2,x=5)

# %%
print(freq)
freq = np.fft.fftfreq(len(ej),t[1]-t[0])
plt.scatter(1/freq,np.abs(np.fft.fft(ej))**2,s=5)
plt.xscale('log')
plt.yscale('log')
plt.show()

plt.scatter(-1/(freq),np.abs(np.fft.fft(ej))**2,s=5)
plt.xscale('log')
plt.yscale('log')
plt.show()

freq = np.fft.fftfreq(len(es),t[1]-t[0])
plt.scatter(1/freq,np.abs(np.fft.fft(es))**2,s=5)
plt.xscale('log')
plt.yscale('log')
plt.show()

plt.scatter(-1/(freq),np.abs(np.fft.fft(ej))**2,s=5)
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
mn = 1.024e26
M=1.989e30
G = 6.674e-11
an = 30.06*1.496e11


def D_diff(an,q):
    return 8/5/np.pi*mn/M*np.sqrt(G*M*an)*np.exp(-(q/an)**2/2)/1.496e11**2*(365*24*60*60)

print(D_diff(30*1.496e11,30.00001*1.496e11))

# %%
qp = (1-ep)*ap

Dp = D_diff(an*1.496e11,qp*1.496e11)

plt.plot(Dp/1.496e11**2*365*24*60*60)

# %%
plt.plot(ap)
plt.show()
plt.plot(ep)
plt.show()

# %%
print(s[0].particles[-1].orbit(primary=s[0].particles[0]))

# %%
x = np.arange(-6,6,0.001)

plt.plot(x,np.abs(np.sinc(x-2))**2)
plt.yscale('log')
plt.xscale('log')
plt.xlim(1.001,6)

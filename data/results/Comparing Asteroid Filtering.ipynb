# %%
import numpy as np
import pandas as pd
import rebound
import matplotlib.pyplot as plt

# %%
InnerRock = pd.read_csv('InnerAst_prop_elem.csv')
InnerGiant = pd.read_csv('Inner4_prop_elem.csv')
InnerNoRock = pd.read_csv('InnerAst_norock_prop_elem.csv')
SampleRock = pd.read_csv('SampleAst_prop_elem.csv')
SampleGiant = pd.read_csv('Sample4_prop_elem.csv')
SampleNoRock = pd.read_csv('SampleAst_norock_prop_elem.csv')

InnerNoMerc = pd.read_csv('Inner_NoMerc_prop_elem.csv')
SampleNoMerc = pd.read_csv('Sample_NoMerc_prop_elem.csv')
InnerNoMerc_nr = pd.read_csv('Inner_NoMerc_norock_prop_elem.csv')
SampleNoMerc_nr = pd.read_csv('Sample_NoMerc_norock_prop_elem.csv')

# %%
fig,ax = plt.subplots(1,2,figsize=(12,4))
ax[0].scatter(InnerRock['PropSMA'],InnerGiant['PropEcc']-InnerRock['PropEcc'])
ax[0].set_xlabel('SMA')
ax[0].set_ylabel('PropEcc Residuals')
ax[0].set_title('InnerRock vs InnerGiant')


ax[1].scatter(InnerRock['PropSMA'],InnerNoRock['PropEcc']-InnerRock['PropEcc'])
ax[1].set_xlabel('SMA')
ax[1].set_ylabel('PropEcc Residuals')
ax[1].set_title('InnerRock vs InnerRock Not Filtered')
plt.show()

fig,ax = plt.subplots(1,2,figsize=(12,4))
ax[0].scatter(InnerRock['PropSMA'],InnerGiant['PropSin(Inc)']-InnerRock['PropSin(Inc)'])
ax[0].set_xlabel('SMA')
ax[0].set_ylabel('PropSin(Inc) Residuals')
ax[0].set_title('InnerRock vs InnerGiant')


ax[1].scatter(InnerRock['PropSMA'],InnerNoRock['PropSin(Inc)']-InnerRock['PropSin(Inc)'])
ax[1].set_xlabel('SMA')
ax[1].set_ylabel('PropSin(Inc) Residuals')
ax[1].set_title('InnerRock vs InnerRock Not Filtered')
plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(12,4))
ax[0].scatter(SampleRock['PropSMA'],SampleGiant['PropEcc']-SampleRock['PropEcc'])
ax[0].set_xlabel('SMA')
ax[0].set_ylabel('PropEcc Residuals')
ax[0].set_title('SampleRock vs SampleGiant')


ax[1].scatter(SampleRock['PropSMA'],SampleNoRock['PropEcc']-SampleRock['PropEcc'])
ax[1].set_xlabel('SMA')
ax[1].set_ylabel('PropEcc Residuals')
ax[1].set_title('SampleRock vs SampleRock Not Filtered')
plt.show()

fig,ax = plt.subplots(1,2,figsize=(12,4))
ax[0].scatter(SampleRock['PropSMA'],SampleGiant['PropSin(Inc)']-SampleRock['PropSin(Inc)'])
ax[0].set_xlabel('SMA')
ax[0].set_ylabel('PropSin(Inc) Residuals')
ax[0].set_title('SampleRock vs SampleGiant')


ax[1].scatter(SampleRock['PropSMA'],SampleNoRock['PropSin(Inc)']-SampleRock['PropSin(Inc)'])
ax[1].set_xlabel('SMA')
ax[1].set_ylabel('PropSin(Inc) Residuals')
ax[1].set_title('SampleRock vs SampleRock Not Filtered')
plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(12,4))
ax[0].scatter(InnerRock['PropSMA'],InnerNoMerc['PropEcc']-InnerRock['PropEcc'])
ax[0].set_xlabel('SMA')
ax[0].set_ylabel('PropEcc Residuals')
ax[0].set_title('InnerNoMerc vs InnerRock Ecc')

ax[1].scatter(InnerRock['PropSMA'],InnerNoMerc_nr['PropEcc']-InnerNoMerc['PropEcc'])
ax[1].set_xlabel('SMA')
ax[1].set_ylabel('PropEcc Residuals')
ax[1].set_title('InnerNoMerc vs InnerMerc Not Filtered Ecc')
plt.show()

fig,ax = plt.subplots(1,2,figsize=(12,4))
ax[0].scatter(InnerRock['PropSMA'],InnerNoMerc['PropSin(Inc)']-InnerRock['PropSin(Inc)'])
ax[0].set_xlabel('SMA')
ax[0].set_ylabel('PropSin(Inc) Residuals')
ax[0].set_title(' InnerNoMerc vs InnerRock Sin(I)')


ax[1].scatter(InnerRock['PropSMA'],InnerNoMerc_nr['PropSin(Inc)']-InnerNoMerc['PropSin(Inc)'])
ax[1].set_xlabel('SMA')
ax[1].set_ylabel('PropSin(Inc) Residuals')
ax[1].set_title('InnerNoMerc vs InnerMerc Not Filtered Sin(I)')
plt.show()

# %%
InnerDF = pd.read_csv('../data_files/InnerAst.csv')
SampleDF = pd.read_csv('../data_files/SampleAst.csv')
#/print(InnerDF)

fig,ax = plt.subplots(1,2,figsize=(12,4))
ax[0].scatter(InnerRock['PropSMA'],InnerRock['PropEcc']-InnerDF['e'])
ax[0].set_title('InnerRock - AstDys Ecc')
ax[1].scatter(InnerRock['PropSMA'],InnerRock['PropSin(Inc)']-InnerDF['sinI'])
ax[1].set_title('InnerRock - AstDys Sin(I)')
plt.show()

fig,ax = plt.subplots(1,2,figsize=(12,4))
ax[0].scatter(InnerRock['PropSMA'],InnerNoRock['PropEcc']-InnerDF['e'])
ax[0].set_title('InnerNoRock - AstDys Ecc')
ax[1].scatter(InnerRock['PropSMA'],InnerNoRock['PropSin(Inc)']-InnerDF['sinI'])
ax[1].set_title('InnerNoRock - AstDys Sin(I)')
plt.show()

fig,ax = plt.subplots(1,2,figsize=(12,4))
ax[0].scatter(InnerRock['PropSMA'],InnerGiant['PropEcc']-InnerDF['e'])
ax[0].set_title('InnerGiant - AstDys Ecc')
x[1].scatter(InnerRock['PropSMA'],InnerGiant['PropSin(Inc)']-InnerDF['sinI'])
ax[1].set_title('InnerGiant - AstDys Sin(I)')
plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(12,4))
ax[0].scatter(InnerRock['PropSMA'],InnerRock['PropEcc']-InnerDF['e'])
ax[0].set_title('InnerRock - AstDys Ecc')
ax[1].scatter(InnerRock['PropSMA'],InnerRock['PropSin(Inc)']-InnerDF['sinI'])
ax[1].set_title('InnerRock - AstDys Sin(I)')
plt.show()

fig,ax = plt.subplots(1,2,figsize=(12,4))
ax[0].scatter(InnerRock['PropSMA'],InnerNoMerc['PropEcc']-InnerDF['e'])
ax[0].set_title('InnerNoMerc - AstDys Ecc')
ax[1].scatter(InnerRock['PropSMA'],InnerNoMerc['PropSin(Inc)']-InnerDF['sinI'])
ax[1].set_title('InnerNoMerc - AstDys Sin(I)')
plt.show()

fig,ax = plt.subplots(1,2,figsize=(12,4))
ax[0].scatter(InnerRock['PropSMA'],InnerNoMerc_nr['PropEcc']-InnerDF['e'])
ax[0].set_title('InnerNoMerc_nr - AstDys Ecc')
ax[1].scatter(InnerRock['PropSMA'],InnerNoMerc_nr['PropSin(Inc)']-InnerDF['sinI'])
ax[1].set_title('InnerNoMerc_nr - AstDys Sin(I)')
plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(12,4))
ax[0].scatter(SampleRock['PropSMA'],SampleRock['PropEcc']-SampleDF['e'])
ax[0].set_title('SampleRock - AstDys Ecc')
ax[1].scatter(SampleRock['PropSMA'],SampleRock['PropSin(Inc)']-SampleDF['sinI'])
ax[1].set_title('SampleRock - AstDys Sin(I)')
plt.show()

fig,ax = plt.subplots(1,2,figsize=(12,4))
ax[0].scatter(SampleRock['PropSMA'],SampleNoRock['PropEcc']-SampleDF['e'])
ax[0].set_title('SampleNoRock - AstDys Ecc')

ax[1].scatter(SampleRock['PropSMA'],SampleNoRock['PropSin(Inc)']-SampleDF['sinI'])
ax[1].set_title('SampleNoRock - AstDys Sin(I)')
plt.show()

fig,ax = plt.subplots(1,2,figsize=(12,4))
ax[0].scatter(SampleRock['PropSMA'],SampleGiant['PropEcc']-SampleDF['e'])
ax[0].set_title('SampleGiant - AstDys Ecc')
ax[1].scatter(SampleRock['PropSMA'],SampleGiant['PropSin(Inc)']-SampleDF['sinI'])
ax[1].set_title('SampleGiant - AstDys Sin(I)')
plt.show()

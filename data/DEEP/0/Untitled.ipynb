# %%
import rebound

# %%
sim = rebound.SimulationArchive('../26/archive_1e8.bin')

num = 30000
print(sim[num].t,len(sim))

rebound.OrbitPlot(sim[num])
# Out:
# 30000000.3617707 100001
# (<Figure size 360x360 with 1 Axes>, <AxesSubplot:xlabel='x', ylabel='y'>)

# %%
sim = rebound.SimulationArchive('../108/archive_1e8.bin')

print(sim[-1].t)

rebound.OrbitPlot(sim[-1])
# Out:
# 82091000.04678063
# (<Figure size 360x360 with 1 Axes>, <AxesSubplot:xlabel='x', ylabel='y'>)

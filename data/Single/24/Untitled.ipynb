# %%
import rebound

s = rebound.Simulationarchive('archive.bin')
print(s[-1].t)

s = rebound.Simulationarchive('../48/archive.bin')
print(s[-1].t)

#s = rebound.Simulationarchive('../24/archive_100.bin')
#print(s[-1].t)

s = rebound.Simulationarchive('../55638/archive_100.bin')
print(s[-1].t)
# Out:
# -10000000.0
# -10000000.0
# -100000000.0

# %%
s = rebound.Simulation('../24/archive_init.bin')
print(len(s.particles))
# Out:
# 9

# %%
import rebound

sim = rebound.Simulation('156/archive_init.bin')
print(sim.particles[5].a)

sim = rebound.Simulationarchive('156/archive.bin')
#print(sim[-1].t)
rebound.OrbitPlot(sim[0])
rebound.OrbitPlot(sim[-1])
print(sim[-1].t)
print(sim[-1].dt)
print(len(sim[-1].particles))
#sim.integrate(100)
# Out:
# 9.54559385991547
# -2168600.011211635
# -0.03
# 9

# %%
import numpy as np
import matplotlib.pyplot as plt
a = np.zeros(len(sim))
e = np.zeros(len(sim))
inc = np.zeros(len(sim))
t = np.zeros(len(sim))
for i in range(len(sim)):
    a[i] = sim[i].particles[8].a
    e[i] = sim[i].particles[8].e
    inc[i] = sim[i].particles[8].inc
    t[i] = sim[i].t
    

plt.scatter(t,a)
plt.show()

plt.scatter(t,e)
plt.show()

plt.scatter(t,inc)
plt.show()
    
a = np.zeros((len(sim),10))
e = np.zeros((len(sim),10))
inc = np.zeros((len(sim),10))
for i in range(len(sim)):
    a[i] = sim[i].particles[5].a
    e[i] = sim[i].particles[5].e
    inc[i] = sim[i].particles[5].inc
    t[i] = sim[i].t

# %%
print(len(sim[-1].particles))
print(len(sim[0].particles))
# Out:
# 16
# 16

# %%
import rebound
sim = rebound.SimulationArchive('78/archive_1.bin')
#print(sim[-1].t)
rebound.OrbitPlot(sim[0])
rebound.OrbitPlot(sim[-1])
print(sim[1].t)
#sim.integrate(100)
# Out:
# 1000.3999999999603

# %%
t = 0
l = (t > 1)
print(l)
# Out:
# False
